# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/MyDrive/')
# Out:
# Mounted at /content/drive

# %%
cd STPM_12_04_2024
# Out:
# /content/drive/MyDrive/STPM_12_04_2024

# %%
# !git clone https://github.com/hcw-00/STPM_anomaly_detection.git
# Out:
# Cloning into 'STPM_anomaly_detection'...
# remote: Enumerating objects: 448, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 448 (delta 0), reused 0 (delta 0), pack-reused 444 (from 1)
# Receiving objects: 100% (448/448), 92.48 MiB | 14.12 MiB/s, done.
# Resolving deltas: 100% (183/183), done.

# %%
cd STPM_anomaly_detection
# Out:
# /content/drive/MyDrive/STPM_12_04_2024/STPM_anomaly_detection

# %%
# !ls /content/drive/MyDrive/mem_seg/data
# Out:
# dtd  MVTec-AD

# %%
# !cp -r /content/drive/MyDrive/mem_seg/data/MVTec-AD/wood /content/drive/MyDrive/STPM_12_04_2024/STPM_anomaly_detection/mvtec_anomaly_detection/

# %%
# Miniconda'yı indirip kur
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local

# Conda'nın Colab ortamına eklenmesi
import sys
sys.path.append('/usr/local/lib/python3.10/site-packages')

# Conda versiyonunu kontrol et
# !conda --version
# Out:
# --2025-04-12 18:45:15--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 154615621 (147M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 147.45M  67.3MB/s    in 2.2s
#
# 2025-04-12 18:45:17 (67.3 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [154615621/154615621]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# conda 25.1.1

# %%
# !conda create -n myenv python=3.8 -y
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.1.1
#     latest version: 25.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-3.0.16             |       h5eee18b_0         5.2 MB
#     pip-24.2                   |   py38h06a4308_0         2.2 MB
#     python-3.8.20              |       he870216_0        23.8 MB
#     setuptools-75.1.0          |   py38h06a4308_0         1.7 MB
#     wheel-0.44.0               |   py38h06a4308_0         108 KB
#     ------------------------------------------------------------
#                                            Total:        33.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2025.2.25-h06a4308_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.40-h12ee557_0
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_1
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-11.2.0-h1234567_1
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-11.2.0-h1234567_1
#   ncurses            pkgs/main/linux-64::ncurses-6.4-h6a678d5_0
#   openssl            pkgs/main/linux-64::openssl-3.0.16-h5eee18b_0
#   pip                pkgs/main/linux-64::pip-24.2-py38h06a4308_0
#   python             pkgs/main/linux-64::python-3.8.20-he870216_0
#   readline           pkgs/main/linux-64::readline-8.2-h5eee18b_0
#   setuptools         pkgs/main/linux-64::setuptools-75.1.0-py38h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.45.3-h5eee18b_0
#   tk                 pkgs/main/linux-64::tk-8.6.14-h39e8969_0
#   wheel              pkgs/main/linux-64::wheel-0.44.0-py38h06a4308_0
#   xz                 pkgs/main/linux-64::xz-5.6.4-h5eee18b_1
#   zlib               pkgs/main/linux-64::zlib-1.2.13-h5eee18b_1
#
#
#
# Downloading and Extracting Packages:
# python-3.8.20        | 23.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
# openssl-3.0.16       | 5.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# pip-24.2             | 2.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# setuptools-75.1.0    | 1.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# wheel-0.44.0         | 108 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# python-3.8.20        | 23.8 MB   | :  11% 0.10515213111926507/1 [00:00<00:00,  1.05it/s]
# openssl-3.0.16       | 5.2 MB    | :  36% 0.3608938679696097/1 [00:00<00:00,  3.60it/s]
#
# pip-24.2             | 2.2 MB    | :  89% 0.8912220595142707/1 [00:00<00:00,  8.91it/s]
#
#
# setuptools-75.1.0    | 1.7 MB    | : 100% 1.0/1 [00:00<00:00,  9.25it/s]
#
#
# setuptools-75.1.0    | 1.7 MB    | : 100% 1.0/1 [00:00<00:00,  9.25it/s]
#
# python-3.8.20        | 23.8 MB   | :  31% 0.30822718434334573/1 [00:00<00:00,  1.62it/s]
#
#
#
# wheel-0.44.0         | 108 KB    | : 100% 1.0/1 [00:00<00:00,  4.65it/s]
#
#
#
# wheel-0.44.0         | 108 KB    | : 100% 1.0/1 [00:00<00:00,  4.65it/s]
# openssl-3.0.16       | 5.2 MB    | : 100% 1.0/1 [00:00<00:00,  3.54it/s]
# python-3.8.20        | 23.8 MB   | : 100% 1.0/1 [00:00<00:00,  2.37it/s]
#
#
# setuptools-75.1.0    | 1.7 MB    | : 100% 1.0/1 [00:01<00:00,  9.25it/s]
#
# pip-24.2             | 2.2 MB    | : 100% 1.0/1 [00:01<00:00,  8.91it/s]
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate myenv
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !conda run -n myenv python --version
# Out:
# Python 3.8.20

# %%
# !conda run -n myenv pip install -r requirements.txt
# Out:
# Collecting opencv-python==4.5.2.52 (from -r requirements.txt (line 1))
#   Downloading opencv_python-4.5.2.52-cp38-cp38-manylinux2014_x86_64.whl.metadata (17 kB)
# Collecting scikit-learn==0.24.2 (from -r requirements.txt (line 2))
#   Downloading scikit_learn-0.24.2-cp38-cp38-manylinux2010_x86_64.whl.metadata (9.8 kB)
# Collecting pytorch-lightning==1.3.3 (from -r requirements.txt (line 3))
#   Downloading pytorch_lightning-1.3.3-py3-none-any.whl.metadata (24 kB)
# Collecting numpy>=1.17.3 (from opencv-python==4.5.2.52->-r requirements.txt (line 1))
#   Downloading numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting scipy>=0.19.1 (from scikit-learn==0.24.2->-r requirements.txt (line 2))
#   Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
# Collecting joblib>=0.11 (from scikit-learn==0.24.2->-r requirements.txt (line 2))
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn==0.24.2->-r requirements.txt (line 2))
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting torch>=1.4 (from pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading torch-2.4.1-cp38-cp38-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting future>=0.17.1 (from pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting tqdm>=4.41.0 (from pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting PyYAML<=5.4.1,>=5.1 (from pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading PyYAML-5.4.1-cp38-cp38-manylinux1_x86_64.whl.metadata (2.1 kB)
# Collecting fsspec>=2021.4.0 (from fsspec[http]>=2021.4.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting tensorboard!=2.5.0,>=2.2.0 (from pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading tensorboard-2.14.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting torchmetrics>=0.2.0 (from pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading torchmetrics-1.5.2-py3-none-any.whl.metadata (20 kB)
# Collecting pyDeprecate==0.3.0 (from pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading pyDeprecate-0.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting packaging (from pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>=2021.4.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading aiohttp-3.10.11-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting absl-py>=0.4 (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading absl_py-2.2.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting grpcio>=1.48.2 (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading grpcio-1.70.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting protobuf>=3.19.6 (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading protobuf-5.29.4-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting requests<3,>=2.21.0 (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/envs/myenv/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3)) (75.1.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: wheel>=0.26 in /usr/local/envs/myenv/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3)) (0.44.0)
# Collecting filelock (from torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.8.0 (from torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy (from torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting jinja2 (from torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading triton-3.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics>=0.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.4.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.4.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.4.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.4.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading frozenlist-1.5.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.4.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading multidict-6.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting yarl<2.0,>=1.12.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.4.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading yarl-1.15.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.4.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting importlib-metadata>=4.4 (from markdown>=2.6.8->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.21.0->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading charset_normalizer-3.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading MarkupSafe-2.1.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=1.4->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting zipp>=3.20 (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading zipp-3.20.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting propcache>=0.2.0 (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.4.0->pytorch-lightning==1.3.3->-r requirements.txt (line 3))
#   Downloading propcache-0.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Downloading opencv_python-4.5.2.52-cp38-cp38-manylinux2014_x86_64.whl (51.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 MB 39.0 MB/s eta 0:00:00
# Downloading scikit_learn-0.24.2-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 134.4 MB/s eta 0:00:00
# Downloading pytorch_lightning-1.3.3-py3-none-any.whl (806 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.2/806.2 kB 38.1 MB/s eta 0:00:00
# Downloading pyDeprecate-0.3.0-py3-none-any.whl (10 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 118.7 MB/s eta 0:00:00
# Downloading PyYAML-5.4.1-cp38-cp38-manylinux1_x86_64.whl (662 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.4/662.4 kB 30.9 MB/s eta 0:00:00
# Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 56.6 MB/s eta 0:00:00
# Downloading tensorboard-2.14.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 111.1 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading torch-2.4.1-cp38-cp38-manylinux1_x86_64.whl (797.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 43.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 42.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 162.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 177.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 39.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 26.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 64.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 63.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 58.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 67.9 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 70.2 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading triton-3.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 72.3 MB/s eta 0:00:00
# Downloading torchmetrics-1.5.2-py3-none-any.whl (891 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 891.4/891.4 kB 43.2 MB/s eta 0:00:00
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading absl_py-2.2.2-py3-none-any.whl (135 kB)
# Downloading aiohttp-3.10.11-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.7 MB/s eta 0:00:00
# Downloading google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
# Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Downloading grpcio-1.70.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 130.7 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
# Downloading protobuf-5.29.4-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 148.9 MB/s eta 0:00:00
# Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 91.8 MB/s eta 0:00:00
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 142.2 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading charset_normalizer-3.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
# Downloading frozenlist-1.5.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (243 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Downloading MarkupSafe-2.1.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 25.2 MB/s eta 0:00:00
# Downloading multidict-6.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Downloading yarl-1.15.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (319 kB)
# Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 53.6 MB/s eta 0:00:00
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Downloading propcache-0.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading zipp-3.20.2-py3-none-any.whl (9.2 kB)
# Installing collected packages: mpmath, zipp, urllib3, typing-extensions, tqdm, threadpoolctl, tensorboard-data-server, sympy, PyYAML, pyDeprecate, pyasn1, protobuf, propcache, packaging, oauthlib, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, joblib, idna, grpcio, future, fsspec, frozenlist, filelock, charset-normalizer, certifi, cachetools, attrs, async-timeout, aiohappyeyeballs, absl-py, werkzeug, triton, scipy, rsa, requests, pyasn1-modules, opencv-python, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multidict, lightning-utilities, jinja2, importlib-metadata, aiosignal, yarl, scikit-learn, requests-oauthlib, nvidia-cusolver-cu12, markdown, google-auth, torch, google-auth-oauthlib, aiohttp, torchmetrics, tensorboard, pytorch-lightning
# Successfully installed MarkupSafe-2.1.5 PyYAML-5.4.1 absl-py-2.2.2 aiohappyeyeballs-2.4.4 aiohttp-3.10.11 aiosignal-1.3.1 async-timeout-5.0.1 attrs-25.3.0 cachetools-5.5.2 certifi-2025.1.31 charset-normalizer-3.4.1 filelock-3.16.1 frozenlist-1.5.0 fsspec-2025.3.0 future-1.0.0 google-auth-2.38.0 google-auth-oauthlib-1.0.0 grpcio-1.70.0 idna-3.10 importlib-metadata-8.5.0 jinja2-3.1.6 joblib-1.4.2 lightning-utilities-0.11.9 markdown-3.7 mpmath-1.3.0 multidict-6.1.0 networkx-3.1 numpy-1.24.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvtx-cu12-12.1.105 oauthlib-3.2.2 opencv-python-4.5.2.52 packaging-24.2 propcache-0.2.0 protobuf-5.29.4 pyDeprecate-0.3.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pytorch-lightning-1.3.3 requests-2.32.3 requests-oauthlib-2.0.0 rsa-4.9 scikit-learn-0.24.2 scipy-1.10.1 sympy-1.13.3 tensorboard-2.14.0 tensorboard-data-server-0.7.2 threadpoolctl-3.5.0 torch-2.4.1 torchmetrics-1.5.2 tqdm-4.67.1 triton-3.0.0 typing-extensions-4.13.2 urllib3-2.2.3 werkzeug-3.0.6 yarl-1.15.2 zipp-3.20.2

# %%
# !conda install -n myenv pytorch torchvision torchaudio -c pytorch -y
# Out:
# Channels:
#  - pytorch
#  - defaults
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.1.1
#     latest version: 25.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - pytorch
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-python-1.0.9        |   py38h6a678d5_8         356 KB
#     certifi-2024.8.30          |   py38h06a4308_0         162 KB
#     cuda-cudart-12.4.127       |       h99ab3db_0          21 KB
#     cuda-cudart_linux-64-12.4.127|       hd681fbe_0         207 KB
#     cuda-cupti-12.4.127        |       h6a678d5_1         2.0 MB
#     cuda-libraries-12.4.1      |       h06a4308_1          19 KB
#     cuda-nvrtc-12.4.127        |       h99ab3db_1        19.8 MB
#     cuda-nvtx-12.4.127         |       h6a678d5_1          30 KB
#     cuda-opencl-12.4.127       |       h6a678d5_0          28 KB
#     cuda-runtime-12.4.1        |       hb982923_0          18 KB
#     cuda-version-12.4          |       hbda6634_3          19 KB
#     filelock-3.13.1            |   py38h06a4308_0          21 KB
#     gmpy2-2.1.2                |   py38heeb90bb_0         191 KB
#     idna-3.7                   |   py38h06a4308_0         113 KB
#     intel-openmp-2023.1.0      |   hdb19cb5_46306        17.2 MB
#     jinja2-3.1.4               |   py38h06a4308_0         275 KB
#     libcublas-12.4.5.8         |       h99ab3db_1       247.6 MB
#     libcufft-11.2.1.3          |       h99ab3db_1       174.5 MB
#     libcufile-1.9.1.3          |       h99ab3db_1         995 KB
#     libcurand-10.3.5.147       |       h99ab3db_1        42.4 MB
#     libcusolver-11.6.1.9       |       h99ab3db_1        83.5 MB
#     libcusparse-12.3.1.170     |       h99ab3db_1       120.0 MB
#     libjpeg-turbo-2.0.0        |       h9bf148f_0         950 KB  pytorch
#     libnpp-12.2.5.30           |       h99ab3db_1       100.5 MB
#     libnvfatbin-12.4.127       |       h7934f7d_2         857 KB
#     libnvjitlink-12.4.127      |       h99ab3db_1        17.4 MB
#     libnvjpeg-12.3.1.117       |       h6a678d5_1         2.6 MB
#     libwebp-1.3.2              |       h11a3e52_0          87 KB
#     libwebp-base-1.3.2         |       h5eee18b_1         425 KB
#     llvm-openmp-14.0.6         |       h9e868ea_0         4.4 MB
#     markupsafe-2.1.3           |   py38h5eee18b_0          22 KB
#     mkl-2023.1.0               |   h213fc3f_46344       171.5 MB
#     mkl-service-2.4.0          |   py38h5eee18b_1          54 KB
#     mkl_fft-1.3.8              |   py38h5eee18b_0         221 KB
#     mkl_random-1.2.4           |   py38hdb19cb5_0         327 KB
#     mpc-1.3.1                  |       h5eee18b_0         129 KB
#     mpfr-4.2.1                 |       h5eee18b_0         821 KB
#     mpmath-1.3.0               |   py38h06a4308_0         832 KB
#     networkx-3.1               |   py38h06a4308_0         2.7 MB
#     numpy-1.24.3               |   py38hf6e8229_1          10 KB
#     numpy-base-1.24.3          |   py38h060ed82_1         6.2 MB
#     ocl-icd-2.3.2              |       h5eee18b_1         136 KB
#     openjpeg-2.5.2             |       he7f1fd0_0         371 KB
#     pillow-10.4.0              |   py38h5eee18b_0         795 KB
#     pysocks-1.7.1              |   py38h06a4308_0          31 KB
#     pytorch-2.4.1              |py3.8_cuda12.4_cudnn9.1.0_0        1.34 GB  pytorch
#     pytorch-cuda-12.4          |       hc786d27_7           7 KB  pytorch
#     pyyaml-6.0.2               |   py38h5eee18b_0         196 KB
#     requests-2.32.3            |   py38h06a4308_0         100 KB
#     sympy-1.13.3               |   py38h06a4308_0        11.2 MB
#     tbb-2021.8.0               |       hdb19cb5_0         1.6 MB
#     torchaudio-2.4.1           |       py38_cu124         6.2 MB  pytorch
#     torchtriton-3.0.0          |             py38       233.4 MB  pytorch
#     torchvision-0.20.0         |       py38_cu124        13.2 MB  pytorch
#     typing_extensions-4.11.0   |   py38h06a4308_0          59 KB
#     urllib3-2.2.3              |   py38h06a4308_0         181 KB
#     yaml-0.2.5                 |       h7b6447c_0          75 KB
#     ------------------------------------------------------------
#                                            Total:        2.60 GB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   brotli-python      pkgs/main/linux-64::brotli-python-1.0.9-py38h6a678d5_8
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h5eee18b_6
#   certifi            pkgs/main/linux-64::certifi-2024.8.30-py38h06a4308_0
#   charset-normalizer pkgs/main/noarch::charset-normalizer-3.3.2-pyhd3eb1b0_0
#   cuda-cudart        pkgs/main/linux-64::cuda-cudart-12.4.127-h99ab3db_0
#   cuda-cudart_linux~ pkgs/main/noarch::cuda-cudart_linux-64-12.4.127-hd681fbe_0
#   cuda-cupti         pkgs/main/linux-64::cuda-cupti-12.4.127-h6a678d5_1
#   cuda-libraries     pkgs/main/linux-64::cuda-libraries-12.4.1-h06a4308_1
#   cuda-nvrtc         pkgs/main/linux-64::cuda-nvrtc-12.4.127-h99ab3db_1
#   cuda-nvtx          pkgs/main/linux-64::cuda-nvtx-12.4.127-h6a678d5_1
#   cuda-opencl        pkgs/main/linux-64::cuda-opencl-12.4.127-h6a678d5_0
#   cuda-runtime       pkgs/main/noarch::cuda-runtime-12.4.1-hb982923_0
#   cuda-version       pkgs/main/noarch::cuda-version-12.4-hbda6634_3
#   ffmpeg             pytorch/linux-64::ffmpeg-4.3-hf484d3e_0
#   filelock           pkgs/main/linux-64::filelock-3.13.1-py38h06a4308_0
#   freetype           pkgs/main/linux-64::freetype-2.13.3-h4a9f257_0
#   giflib             pkgs/main/linux-64::giflib-5.2.2-h5eee18b_0
#   gmp                pkgs/main/linux-64::gmp-6.3.0-h6a678d5_0
#   gmpy2              pkgs/main/linux-64::gmpy2-2.1.2-py38heeb90bb_0
#   gnutls             pkgs/main/linux-64::gnutls-3.6.15-he1e5248_0
#   idna               pkgs/main/linux-64::idna-3.7-py38h06a4308_0
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2023.1.0-hdb19cb5_46306
#   jinja2             pkgs/main/linux-64::jinja2-3.1.4-py38h06a4308_0
#   jpeg               pkgs/main/linux-64::jpeg-9e-h5eee18b_3
#   lame               pkgs/main/linux-64::lame-3.100-h7b6447c_0
#   lcms2              pkgs/main/linux-64::lcms2-2.16-hb9589c4_0
#   lerc               pkgs/main/linux-64::lerc-4.0.0-h6a678d5_0
#   libcublas          pkgs/main/linux-64::libcublas-12.4.5.8-h99ab3db_1
#   libcufft           pkgs/main/linux-64::libcufft-11.2.1.3-h99ab3db_1
#   libcufile          pkgs/main/linux-64::libcufile-1.9.1.3-h99ab3db_1
#   libcurand          pkgs/main/linux-64::libcurand-10.3.5.147-h99ab3db_1
#   libcusolver        pkgs/main/linux-64::libcusolver-11.6.1.9-h99ab3db_1
#   libcusparse        pkgs/main/linux-64::libcusparse-12.3.1.170-h99ab3db_1
#   libdeflate         pkgs/main/linux-64::libdeflate-1.22-h5eee18b_0
#   libiconv           pkgs/main/linux-64::libiconv-1.16-h5eee18b_3
#   libidn2            pkgs/main/linux-64::libidn2-2.3.4-h5eee18b_0
#   libjpeg-turbo      pytorch/linux-64::libjpeg-turbo-2.0.0-h9bf148f_0
#   libnpp             pkgs/main/linux-64::libnpp-12.2.5.30-h99ab3db_1
#   libnvfatbin        pkgs/main/linux-64::libnvfatbin-12.4.127-h7934f7d_2
#   libnvjitlink       pkgs/main/linux-64::libnvjitlink-12.4.127-h99ab3db_1
#   libnvjpeg          pkgs/main/linux-64::libnvjpeg-12.3.1.117-h6a678d5_1
#   libpng             pkgs/main/linux-64::libpng-1.6.39-h5eee18b_0
#   libtasn1           pkgs/main/linux-64::libtasn1-4.19.0-h5eee18b_0
#   libtiff            pkgs/main/linux-64::libtiff-4.5.1-hffd6297_1
#   libunistring       pkgs/main/linux-64::libunistring-0.9.10-h27cfd23_0
#   libwebp            pkgs/main/linux-64::libwebp-1.3.2-h11a3e52_0
#   libwebp-base       pkgs/main/linux-64::libwebp-base-1.3.2-h5eee18b_1
#   llvm-openmp        pkgs/main/linux-64::llvm-openmp-14.0.6-h9e868ea_0
#   lz4-c              pkgs/main/linux-64::lz4-c-1.9.4-h6a678d5_1
#   markupsafe         pkgs/main/linux-64::markupsafe-2.1.3-py38h5eee18b_0
#   mkl                pkgs/main/linux-64::mkl-2023.1.0-h213fc3f_46344
#   mkl-service        pkgs/main/linux-64::mkl-service-2.4.0-py38h5eee18b_1
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.3.8-py38h5eee18b_0
#   mkl_random         pkgs/main/linux-64::mkl_random-1.2.4-py38hdb19cb5_0
#   mpc                pkgs/main/linux-64::mpc-1.3.1-h5eee18b_0
#   mpfr               pkgs/main/linux-64::mpfr-4.2.1-h5eee18b_0
#   mpmath             pkgs/main/linux-64::mpmath-1.3.0-py38h06a4308_0
#   nettle             pkgs/main/linux-64::nettle-3.7.3-hbbd107a_1
#   networkx           pkgs/main/linux-64::networkx-3.1-py38h06a4308_0
#   numpy              pkgs/main/linux-64::numpy-1.24.3-py38hf6e8229_1
#   numpy-base         pkgs/main/linux-64::numpy-base-1.24.3-py38h060ed82_1
#   ocl-icd            pkgs/main/linux-64::ocl-icd-2.3.2-h5eee18b_1
#   openh264           pkgs/main/linux-64::openh264-2.1.1-h4ff587b_0
#   openjpeg           pkgs/main/linux-64::openjpeg-2.5.2-he7f1fd0_0
#   pillow             pkgs/main/linux-64::pillow-10.4.0-py38h5eee18b_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py38h06a4308_0
#   pytorch            pytorch/linux-64::pytorch-2.4.1-py3.8_cuda12.4_cudnn9.1.0_0
#   pytorch-cuda       pytorch/linux-64::pytorch-cuda-12.4-hc786d27_7
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cuda
#   pyyaml             pkgs/main/linux-64::pyyaml-6.0.2-py38h5eee18b_0
#   requests           pkgs/main/linux-64::requests-2.32.3-py38h06a4308_0
#   sympy              pkgs/main/linux-64::sympy-1.13.3-py38h06a4308_0
#   tbb                pkgs/main/linux-64::tbb-2021.8.0-hdb19cb5_0
#   torchaudio         pytorch/linux-64::torchaudio-2.4.1-py38_cu124
#   torchtriton        pytorch/linux-64::torchtriton-3.0.0-py38
#   torchvision        pytorch/linux-64::torchvision-0.20.0-py38_cu124
#   typing_extensions  pkgs/main/linux-64::typing_extensions-4.11.0-py38h06a4308_0
#   urllib3            pkgs/main/linux-64::urllib3-2.2.3-py38h06a4308_0
#   yaml               pkgs/main/linux-64::yaml-0.2.5-h7b6447c_0
#   zstd               pkgs/main/linux-64::zstd-1.5.6-hc292b87_0
#
#
#
# Downloading and Extracting Packages:
# pytorch-2.4.1        | 1.34 GB   | :   0% 0/1 [00:00<?, ?it/s]
# libcublas-12.4.5.8   | 247.6 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
# torchtriton-3.0.0    | 233.4 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libcusolver-11.6.1.9 | 83.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 19.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.4.12 | 17.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 17.2 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.20.0   | 13.2 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# sympy-1.13.3         | 11.2 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.4.1     | 6.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-base-1.24.3    | 6.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.1         | 2.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-12.3.1.117 | 2.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :   0% 0.0003870052273786807/1 [00:00<04:18, 258.44s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :   1% 0.00637380240504594/1 [00:00<00:15, 15.82s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :   1% 0.007104816987772907/1 [00:00<00:13, 14.08s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :   1% 0.006984977105659033/1 [00:00<00:14, 15.00s/it]
#
# pytorch-2.4.1        | 1.34 GB   | :   0% 0.0036651671534098586/1 [00:00<00:47, 47.91s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :   2% 0.02208743407689187/1 [00:00<00:08,  8.83s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :   2% 0.02262868918950344/1 [00:00<00:08,  8.45s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :   3% 0.030332103293953562/1 [00:00<00:06,  6.41s/it]
#
#
# pytorch-2.4.1        | 1.34 GB   | :   1% 0.006305908704934974/1 [00:00<00:43, 43.49s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :   3% 0.03332047197885402/1 [00:00<00:08,  8.98s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :   4% 0.043115017272308334/1 [00:00<00:06,  6.39s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :   6% 0.05713353068474952/1 [00:00<00:04,  4.97s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :   1% 0.009197065403587472/1 [00:00<00:39, 39.54s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :   5% 0.04650982547048374/1 [00:00<00:07,  8.39s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :   6% 0.0590488280033788/1 [00:00<00:06,  6.47s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :   9% 0.08580432823694972/1 [00:00<00:04,  4.41s/it]
#
#
# pytorch-2.4.1        | 1.34 GB   | :   1% 0.012133752128990401/1 [00:00<00:37, 38.43s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :   6% 0.061718601506286434/1 [00:00<00:07,  7.91s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :   8% 0.07786143647157545/1 [00:00<00:05,  6.19s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  11% 0.11431468358532049/1 [00:00<00:03,  4.09s/it]
#
#
# pytorch-2.4.1        | 1.34 GB   | :   2% 0.015036291334330506/1 [00:00<00:37, 38.16s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :   7% 0.0743399924073675/1 [00:00<00:07,  8.21s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :   9% 0.09412999112556758/1 [00:00<00:05,  6.62s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  12% 0.12375946615411261/1 [00:00<00:04,  5.02s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :   2% 0.017654267872480405/1 [00:00<00:41, 42.23s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :   9% 0.08651963462691073/1 [00:00<00:08,  8.79s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  11% 0.10939431401079475/1 [00:00<00:06,  7.42s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  14% 0.1437293365972147/1 [00:00<00:05,  5.86s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :   2% 0.020067359290253356/1 [00:00<00:42, 43.55s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  10% 0.09800510034689451/1 [00:00<00:08,  9.10s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  12% 0.123252712419751/1 [00:00<00:06,  7.70s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  16% 0.16172908529256683/1 [00:00<00:04,  5.83s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  18% 0.18089957099637172/1 [00:00<00:04,  5.54s/it]
# pytorch-2.4.1        | 1.34 GB   | :   2% 0.02251459822808913/1 [00:00<00:42, 43.64s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  18% 0.18160940474713486/1 [00:01<00:04,  5.61s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  14% 0.1365085717674483/1 [00:01<00:06,  8.04s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  21% 0.20840796497467193/1 [00:01<00:03,  4.86s/it]
# pytorch-2.4.1        | 1.34 GB   | :   3% 0.025030132206050555/1 [00:01<00:42, 43.12s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  20% 0.19987780640808925/1 [00:01<00:04,  5.76s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  15% 0.1496305335459769/1 [00:01<00:06,  7.92s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  24% 0.23518765977473904/1 [00:01<00:03,  4.50s/it]
# pytorch-2.4.1        | 1.34 GB   | :   3% 0.027363546077010248/1 [00:01<00:43, 45.19s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  23% 0.22611624604857766/1 [00:01<00:03,  5.04s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  17% 0.165899088199969/1 [00:01<00:06,  7.34s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  26% 0.25832385868364055/1 [00:01<00:03,  4.53s/it]
# pytorch-2.4.1        | 1.34 GB   | :   3% 0.03001567013522297/1 [00:01<00:41, 42.84s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  25% 0.24698162637702067/1 [00:01<00:03,  4.96s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  19% 0.1854481332985933/1 [00:01<00:05,  6.53s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :   3% 0.0324059965396207/1 [00:01<00:41, 42.61s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  17% 0.17329169707184308/1 [00:01<00:06,  7.50s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  27% 0.27160814822389545/1 [00:01<00:03,  4.66s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  20% 0.2039259978438683/1 [00:01<00:04,  6.21s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :   4% 0.03576383601246514/1 [00:01<00:36, 37.89s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  19% 0.18673347838149443/1 [00:01<00:06,  7.66s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  22% 0.22119878426662537/1 [00:01<00:04,  6.08s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  29% 0.29336903843767936/1 [00:01<00:03,  4.78s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :   4% 0.03851840263086634/1 [00:01<00:36, 37.45s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  20% 0.20263643091685657/1 [00:01<00:05,  7.38s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  24% 0.23827072433562943/1 [00:01<00:04,  6.11s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  32% 0.3182642132501564/1 [00:01<00:03,  4.57s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :   4% 0.041216056715829494/1 [00:01<00:37, 38.97s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  22% 0.22339861894913493/1 [00:01<00:04,  6.42s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  26% 0.25748502551133207/1 [00:01<00:04,  5.84s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  34% 0.3403833074180767/1 [00:01<00:03,  4.66s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :   4% 0.043811268240604176/1 [00:01<00:37, 39.68s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  24% 0.23917535757548627/1 [00:01<00:05,  6.64s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  28% 0.277569660886631/1 [00:01<00:04,  5.56s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  36% 0.36196509565479246/1 [00:01<00:03,  4.78s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :   5% 0.04694145757969645/1 [00:01<00:35, 37.12s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  26% 0.2550783101108484/1 [00:01<00:04,  6.55s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  30% 0.2956458327244/1 [00:01<00:04,  5.69s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  38% 0.38354688389150815/1 [00:01<00:03,  5.03s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :   5% 0.04966187667803482/1 [00:02<00:39, 41.13s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  31% 0.313320311854663/1 [00:02<00:04,  5.99s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  27% 0.27047640701016734/1 [00:02<00:05,  7.10s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  41% 0.40933756858932613/1 [00:02<00:02,  4.65s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  43% 0.43302948666503077/1 [00:02<00:02,  4.80s/it]
#
# pytorch-2.4.1        | 1.34 GB   | :   5% 0.05305386367094208/1 [00:02<00:36, 38.04s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  29% 0.2866317873635511/1 [00:02<00:04,  7.00s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  43% 0.4322626216540532/1 [00:02<00:02,  4.64s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  46% 0.45534589899842004/1 [00:02<00:02,  4.75s/it]
#
# pytorch-2.4.1        | 1.34 GB   | :   6% 0.055831195302718496/1 [00:02<00:35, 37.49s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  30% 0.30360755812550516/1 [00:02<00:04,  6.66s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  46% 0.45608318460412123/1 [00:02<00:02,  4.51s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :   6% 0.05854023189436926/1 [00:02<00:35, 37.48s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  32% 0.31881633416130783/1 [00:02<00:04,  6.68s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  36% 0.36373274664666333/1 [00:02<00:04,  6.33s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  48% 0.47847093173764377/1 [00:02<00:02,  4.58s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :   6% 0.061579361179960664/1 [00:02<00:33, 36.05s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  34% 0.3359814257867781/1 [00:02<00:04,  6.41s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  38% 0.3796665573777338/1 [00:02<00:04,  6.58s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  50% 0.5004109239284958/1 [00:02<00:02,  4.78s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  52% 0.524390146136008/1 [00:02<00:02,  4.55s/it]
# pytorch-2.4.1        | 1.34 GB   | :   6% 0.0643794578251123/1 [00:02<00:36, 38.67s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  52% 0.5245896908327001/1 [00:02<00:02,  4.58s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  39% 0.39499782904754527/1 [00:02<00:04,  6.69s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  55% 0.5490748307986549/1 [00:02<00:01,  4.39s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  55% 0.5504699265190522/1 [00:02<00:01,  4.37s/it]
# pytorch-2.4.1        | 1.34 GB   | :   7% 0.0670088168699498/1 [00:02<00:37, 40.35s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  57% 0.571937767515719/1 [00:02<00:02,  4.88s/it]
#
# pytorch-2.4.1        | 1.34 GB   | :   7% 0.06996826860872794/1 [00:02<00:35, 38.38s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  57% 0.5735740815608475/1 [00:02<00:01,  4.43s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  38% 0.38198639562121856/1 [00:02<00:04,  7.16s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  43% 0.42572732117175266/1 [00:02<00:04,  7.19s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :   7% 0.07342855064176086/1 [00:02<00:32, 35.17s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  40% 0.39959323592822665/1 [00:02<00:04,  6.67s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  60% 0.5962304816599723/1 [00:02<00:01,  4.72s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  44% 0.4411255416261485/1 [00:02<00:03,  7.00s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :   8% 0.07661565251429117/1 [00:03<00:31, 34.55s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  62% 0.6176331679196199/1 [00:03<00:01,  4.71s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  41% 0.4148020119640294/1 [00:03<00:04,  7.22s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  46% 0.45819748169515256/1 [00:03<00:03,  6.64s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :   8% 0.07954095673300648/1 [00:03<00:32, 35.47s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  64% 0.6429760976747674/1 [00:03<00:01,  4.47s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  43% 0.4324719592255429/1 [00:03<00:03,  6.72s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  48% 0.4754702681179096/1 [00:03<00:03,  6.37s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :   8% 0.08238658340490855/1 [00:03<00:33, 36.50s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  67% 0.6655429467853581/1 [00:03<00:01,  4.58s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  50% 0.4968269304003108/1 [00:03<00:02,  5.77s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  45% 0.44768073526134555/1 [00:03<00:03,  6.71s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  69% 0.6923553067187419/1 [00:03<00:01,  4.75s/it]
#
#
# pytorch-2.4.1        | 1.34 GB   | :   9% 0.08515253252999737/1 [00:03<00:34, 37.50s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  51% 0.5147022558843268/1 [00:03<00:02,  5.72s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  46% 0.46333125997868607/1 [00:03<00:03,  6.62s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  71% 0.7143984568602937/1 [00:03<00:01,  4.69s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  72% 0.717124316180994/1 [00:03<00:01,  4.29s/it]
# pytorch-2.4.1        | 1.34 GB   | :   9% 0.08922746992416111/1 [00:03<00:31, 34.09s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  53% 0.5323767350145898/1 [00:03<00:02,  6.22s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  74% 0.7359861700154499/1 [00:03<00:01,  4.99s/it]
#
#
# pytorch-2.4.1        | 1.34 GB   | :   9% 0.09217553915625165/1 [00:03<00:30, 34.05s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  50% 0.49955465186478876/1 [00:03<00:03,  6.24s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  55% 0.5487791872377507/1 [00:03<00:02,  6.28s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  76% 0.7570273587869312/1 [00:03<00:01,  5.03s/it]
#
#
# pytorch-2.4.1        | 1.34 GB   | :  10% 0.09511222588165459/1 [00:03<00:32, 35.73s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  52% 0.5157100322181725/1 [00:03<00:03,  6.65s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  56% 0.5649807931071584/1 [00:03<00:02,  6.32s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  10% 0.09837900530099815/1 [00:03<00:30, 34.14s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  79% 0.7858994753751752/1 [00:03<00:01,  4.69s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  53% 0.5309188082539752/1 [00:03<00:03,  6.88s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  58% 0.5809815526228133/1 [00:03<00:02,  6.45s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  10% 0.10150919464009042/1 [00:03<00:30, 33.90s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  81% 0.8075708146004251/1 [00:03<00:00,  4.73s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  60% 0.5994594171680883/1 [00:03<00:02,  6.12s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  55% 0.5456227286537346/1 [00:03<00:03,  7.21s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  82% 0.8191489637313045/1 [00:03<00:00,  4.97s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  84% 0.8372121918052089/1 [00:03<00:00,  4.25s/it]
#
# pytorch-2.4.1        | 1.34 GB   | :  10% 0.10448002888555619/1 [00:04<00:32, 36.71s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  56% 0.5633557828697535/1 [00:04<00:02,  6.70s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  84% 0.8393703659272735/1 [00:04<00:00,  4.97s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | :  86% 0.8609432037667428/1 [00:04<00:01, 11.70s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  86% 0.8595917681232426/1 [00:04<00:02, 14.45s/it]
# pytorch-2.4.1        | 1.34 GB   | :  11% 0.10724597801064499/1 [00:05<01:58, 132.71s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  63% 0.6320634752606568/1 [00:05<00:08, 23.93s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  87% 0.8745301012770215/1 [00:06<00:04, 32.93s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  59% 0.5896713828985076/1 [00:06<00:18, 46.24s/it]
#
#
# pytorch-2.4.1        | 1.34 GB   | :  11% 0.10926068169435164/1 [00:06<03:59, 268.45s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  64% 0.6438464613474988/1 [00:06<00:17, 47.83s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  89% 0.8853695015532391/1 [00:07<00:05, 46.04s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  60% 0.5977490730751994/1 [00:07<00:26, 64.93s/it]
#
#
# pytorch-2.4.1        | 1.34 GB   | :  11% 0.11071764255036551/1 [00:07<05:05, 343.21s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  65% 0.6523489569897087/1 [00:07<00:20, 60.03s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  89% 0.8932941051165243/1 [00:07<00:04, 44.42s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  61% 0.6082248275230967/1 [00:07<00:19, 50.39s/it]
#
#
# pytorch-2.4.1        | 1.34 GB   | :  11% 0.1133356190885154/1 [00:07<03:36, 244.02s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  67% 0.6676132798749359/1 [00:07<00:14, 42.34s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  92% 0.915883779641751/1 [00:07<00:02, 28.05s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  63% 0.6281035181922995/1 [00:07<00:11, 31.55s/it]
#
#
# pytorch-2.4.1        | 1.34 GB   | :  12% 0.1159422131199777/1 [00:07<02:38, 179.17s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  68% 0.6832792954676691/1 [00:07<00:09, 30.63s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  94% 0.9365606188241158/1 [00:07<00:01, 19.96s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  65% 0.6466569628168886/1 [00:07<00:07, 22.22s/it]
#
#
# pytorch-2.4.1        | 1.34 GB   | :  12% 0.11894719488550627/1 [00:07<01:53, 129.21s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  70% 0.6988783622758179/1 [00:07<00:06, 22.95s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  96% 0.9597879051302964/1 [00:07<00:00, 14.34s/it]
# libcublas-12.4.5.8   | 247.6 MB  | :  66% 0.6638851613968643/1 [00:07<00:05, 16.96s/it]
#
#
# pytorch-2.4.1        | 1.34 GB   | :  12% 0.12169037899721986/1 [00:07<01:28, 100.58s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  72% 0.7180257146669361/1 [00:07<00:04, 16.62s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | :  98% 0.9796449577371489/1 [00:07<00:00, 11.51s/it]
# pytorch-2.4.1        | 1.34 GB   | :  12% 0.12466121324268561/1 [00:08<01:09, 79.26s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  74% 0.7350976547359402/1 [00:08<00:03, 13.27s/it]
# pytorch-2.4.1        | 1.34 GB   | :  13% 0.12765481250152658/1 [00:08<00:56, 65.01s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  75% 0.7540441607733055/1 [00:08<00:02, 11.01s/it]
# pytorch-2.4.1        | 1.34 GB   | :  13% 0.13093297442755777/1 [00:08<00:47, 54.38s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  77% 0.7727898204569179/1 [00:08<00:02,  9.29s/it]
# pytorch-2.4.1        | 1.34 GB   | :  13% 0.13368754104595895/1 [00:08<00:43, 50.38s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  80% 0.7956863047847587/1 [00:08<00:01,  7.55s/it]
# pytorch-2.4.1        | 1.34 GB   | :  14% 0.13686326041180166/1 [00:08<00:38, 44.36s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  81% 0.8136955278379433/1 [00:08<00:01,  7.00s/it]
# pytorch-2.4.1        | 1.34 GB   | :  14% 0.13989100719070546/1 [00:08<00:35, 41.15s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  83% 0.8318386484602966/1 [00:08<00:01,  6.56s/it]
# pytorch-2.4.1        | 1.34 GB   | :  14% 0.14328299418361273/1 [00:08<00:32, 37.39s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  85% 0.8525258228968545/1 [00:08<00:00,  6.05s/it]
# pytorch-2.4.1        | 1.34 GB   | :  15% 0.14674327621664562/1 [00:08<00:29, 34.67s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  87% 0.8721418167800632/1 [00:08<00:00,  5.82s/it]
# pytorch-2.4.1        | 1.34 GB   | :  15% 0.15059056347705724/1 [00:08<00:27, 31.97s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  89% 0.8935654278470486/1 [00:08<00:00,  5.57s/it]
# pytorch-2.4.1        | 1.34 GB   | :  15% 0.15392563793652644/1 [00:08<00:26, 31.88s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  92% 0.9203449416807805/1 [00:09<00:00,  5.13s/it]
# pytorch-2.4.1        | 1.34 GB   | :  16% 0.1581257829042539/1 [00:09<00:24, 29.24s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  94% 0.9406304234098325/1 [00:09<00:00,  5.09s/it]
# pytorch-2.4.1        | 1.34 GB   | :  16% 0.16168850749747526/1 [00:09<00:24, 28.95s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  96% 0.9607820075697157/1 [00:09<00:00,  5.22s/it]
# pytorch-2.4.1        | 1.34 GB   | :  17% 0.16522846707732144/1 [00:09<00:24, 29.22s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | :  98% 0.98033105266834/1 [00:09<00:00,  5.34s/it]
# pytorch-2.4.1        | 1.34 GB   | :  17% 0.1689050167374189/1 [00:09<00:23, 28.60s/it]
# pytorch-2.4.1        | 1.34 GB   | :  17% 0.17321898677202244/1 [00:09<00:22, 26.78s/it]
# pytorch-2.4.1        | 1.34 GB   | :  21% 0.21042840113381384/1 [00:10<00:20, 26.27s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | : 100% 1.0/1 [00:10<00:00, 46.75s/it]
#
#
# libcufft-11.2.1.3    | 174.5 MB  | : 100% 1.0/1 [00:10<00:00, 46.75s/it]
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  21% 0.21462854610154128/1 [00:10<00:20, 25.57s/it]
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  22% 0.21860104093551655/1 [00:10<00:22, 29.00s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :   8% 0.0848611279039229/1 [00:10<01:08, 74.53s/it]
#
#
#
# mkl-2023.1.0         | 171.5 MB  | : 100% 1.0/1 [00:10<00:00, 51.76s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  22% 0.22218653054211315/1 [00:10<00:23, 30.77s/it]
#
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  | :   0% 0.00015547846604740422/1 [00:10<19:24:28, 69879.08s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  12% 0.12338703873147074/1 [00:10<00:38, 43.68s/it]
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  23% 0.22554437001495758/1 [00:11<00:26, 34.44s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  16% 0.15826860664289916/1 [00:11<00:27, 32.35s/it]
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  23% 0.22857211679386139/1 [00:11<00:46, 60.32s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  19% 0.18859474590917838/1 [00:11<00:19, 23.62s/it]
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  23% 0.23090553066482108/1 [00:11<00:43, 57.19s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  21% 0.2130639054888371/1 [00:11<00:14, 18.75s/it]
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  23% 0.23319341450903033/1 [00:11<00:44, 57.99s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  24% 0.23870446100581996/1 [00:11<00:11, 14.76s/it]
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  24% 0.23537885579305112/1 [00:11<00:43, 56.28s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  27% 0.26785920433477506/1 [00:11<00:08, 11.27s/it]
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  24% 0.2379626848111382/1 [00:11<00:40, 53.72s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  29% 0.2919378986019925/1 [00:11<00:06,  9.37s/it]
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  24% 0.2400343010282829/1 [00:12<00:39, 52.54s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  32% 0.31588643776506276/1 [00:12<00:05,  7.93s/it]
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  24% 0.24212868225880282/1 [00:12<00:38, 51.28s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  34% 0.33983497692813297/1 [00:12<00:04,  6.94s/it]
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  24% 0.24421168098263513/1 [00:12<00:39, 52.68s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  37% 0.36612630796585144/1 [00:12<00:03,  6.06s/it]
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  25% 0.246772744987347/1 [00:12<00:37, 49.63s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  39% 0.3930684145243055/1 [00:12<00:03,  5.41s/it]
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  25% 0.24910615885830667/1 [00:12<00:36, 48.75s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  42% 0.4197502108744653/1 [00:12<00:02,  4.93s/it]
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  25% 0.2512119225955142/1 [00:12<00:38, 52.01s/it]
#
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  | :  39% 0.3918057344394586/1 [00:12<00:02,  4.55s/it]
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  25% 0.2535567189731615/1 [00:12<00:36, 49.53s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  47% 0.46881868513792996/1 [00:12<00:02,  4.80s/it]
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  26% 0.2556169526836186/1 [00:12<00:37, 50.78s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  49% 0.4921164487802646/1 [00:12<00:02,  4.77s/it]
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  26% 0.2576202738606376/1 [00:12<00:37, 51.15s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  52% 0.5158046777350406/1 [00:12<00:02,  4.63s/it]
#
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  | :  48% 0.479651067756242/1 [00:12<00:02,  3.96s/it]
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  26% 0.2599195402115345/1 [00:13<00:37, 51.13s/it]
#
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  | :  51% 0.508881019373154/1 [00:13<00:01,  3.96s/it]
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  26% 0.26220742405574377/1 [00:13<00:36, 48.85s/it]
#
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  | :  54% 0.5419979326412511/1 [00:13<00:01,  3.65s/it]
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  26% 0.2642790402728885/1 [00:13<00:36, 49.85s/it]
#
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  | :  57% 0.5710724057921157/1 [00:13<00:01,  3.74s/it]
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  27% 0.2663165089699704/1 [00:13<00:36, 50.36s/it]
#
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  | :  60% 0.5998359220108854/1 [00:13<00:01,  3.67s/it]
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  27% 0.2684791852406159/1 [00:13<00:36, 49.32s/it]
#
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  | :  63% 0.6315535290845559/1 [00:13<00:01,  3.59s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  66% 0.6637910311503172/1 [00:13<00:01,  4.28s/it]
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  27% 0.27098333671188973/1 [00:13<00:35, 49.30s/it]
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  27% 0.27318016050259813/1 [00:13<00:35, 48.37s/it]
#
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  | :  69% 0.6906353461825695/1 [00:13<00:01,  3.65s/it]
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  28% 0.2758891970942489/1 [00:13<00:32, 44.45s/it]
#
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  | :  72% 0.7245296517809037/1 [00:13<00:00,  3.48s/it]
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  28% 0.27815431592508294/1 [00:13<00:33, 46.25s/it]
#
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  | :  76% 0.7615335267001858/1 [00:13<00:00,  3.32s/it]
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  28% 0.28088611753010895/1 [00:13<00:31, 44.12s/it]
#
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  | :  79% 0.7937175691719985/1 [00:13<00:00,  3.26s/it]
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  28% 0.28343579902813315/1 [00:14<00:31, 43.34s/it]
#
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  | :  83% 0.8325871856838496/1 [00:14<00:00,  3.25s/it]
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  29% 0.2857919779124681/1 [00:14<00:31, 43.82s/it]
#
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  | :  86% 0.863527400427283/1 [00:14<00:00,  3.25s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  85% 0.8516048464346129/1 [00:14<00:00,  3.92s/it]
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  29% 0.28846686698405605/1 [00:14<00:32, 45.23s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  88% 0.8773755570557429/1 [00:14<00:00,  3.97s/it]
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  29% 0.29069783829482726/1 [00:14<00:32, 45.27s/it]
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  29% 0.29291742709891083/1 [00:14<00:32, 46.11s/it]
#
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  | :  97% 0.9655212741543802/1 [00:14<00:00,  3.23s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | :  93% 0.9321708559016808/1 [00:14<00:00,  3.97s/it]
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  30% 0.29537604854343424/1 [00:14<00:33, 47.16s/it]
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  30% 0.29750457729401697/1 [00:14<00:35, 50.48s/it]
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  30% 0.30435684631995713/1 [00:15<00:33, 48.28s/it]
#
# torchtriton-3.0.0    | 233.4 MB  | : 100% 1.0/1 [00:15<00:00, 89.35s/it]
#
# pytorch-2.4.1        | 1.34 GB   | :  31% 0.3066674951775416/1 [00:15<00:33, 48.51s/it]
#
#
#
#
#
#
# libcusolver-11.6.1.9 | 83.5 MB   | :   0% 0.0001871742864388745/1 [00:15<22:33:36, 81231.29s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  31% 0.30961556440963217/1 [00:15<00:31, 45.11s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  31% 0.3118351532137158/1 [00:15<00:32, 47.63s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  32% 0.31604668068813085/1 [00:15<00:33, 48.74s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  32% 0.3183004170122773/1 [00:15<00:32, 47.48s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  32% 0.32103221861730324/1 [00:15<00:30, 44.35s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  32% 0.32329733744813727/1 [00:15<00:31, 46.22s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  33% 0.32547139622547044/1 [00:16<00:31, 46.78s/it]
#
#
#
#
#
#
# libcusolver-11.6.1.9 | 83.5 MB   | :  25% 0.25362115812467495/1 [00:16<00:08, 11.26s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  33% 0.32762268998942845/1 [00:16<00:32, 48.34s/it]
# libcublas-12.4.5.8   | 247.6 MB  | : 100% 1.0/1 [00:16<00:00,  4.61s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  33% 0.3299788688737633/1 [00:16<00:31, 46.53s/it]
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  33% 0.33218707517115936/1 [00:16<00:30, 46.17s/it]
#
#
#
#
#
#
# libcusolver-11.6.1.9 | 83.5 MB   | :  38% 0.377343361460771/1 [00:16<00:03,  5.15s/it]
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  33% 0.3347481391758712/1 [00:16<00:29, 44.13s/it]
#
#
#
#
#
#
# libcusolver-11.6.1.9 | 83.5 MB   | :  41% 0.41421669588922927/1 [00:16<00:02,  4.51s/it]
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  34% 0.33702464051339287/1 [00:16<00:31, 47.30s/it]
#
#
#
#
#
#
# libcusolver-11.6.1.9 | 83.5 MB   | :  45% 0.4499669845990543/1 [00:16<00:02,  4.22s/it]
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | :  23% 0.22645576199850376/1 [00:16<00:26, 34.37s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  34% 0.3391645517706632/1 [00:16<00:32, 49.84s/it]
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | :  30% 0.3034138990028733/1 [00:16<00:14, 21.52s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  34% 0.34120202046774506/1 [00:16<00:34, 52.37s/it]
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | :  37% 0.3726394002316842/1 [00:16<00:09, 14.85s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  34% 0.3431370466046385/1 [00:16<00:36, 56.14s/it]
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | :  44% 0.4385509146995414/1 [00:16<00:06, 10.79s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  35% 0.3458119356762264/1 [00:17<00:32, 49.57s/it]
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | :  50% 0.5037259876649645/1 [00:17<00:03,  7.96s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  35% 0.348816917441755/1 [00:17<00:28, 43.89s/it]
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | :  57% 0.566691736123085/1 [00:17<00:02,  6.09s/it]
#
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  | : 100% 1.0/1 [00:17<00:00,  3.24s/it]
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 19.8 MB   | :   0% 0.0007873928334276324/1 [00:17<6:04:29, 21886.91s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  35% 0.3514348939799049/1 [00:17<00:27, 42.15s/it]
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | :  64% 0.6407041071177179/1 [00:17<00:01,  4.51s/it]
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 19.8 MB   | :  13% 0.1259828533484212/1 [00:17<01:24, 96.74s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  35% 0.3539504279578663/1 [00:17<00:28, 43.63s/it]
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 19.8 MB   | :  25% 0.2503909210299871/1 [00:17<00:30, 40.59s/it]
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | :  71% 0.705879180083141/1 [00:17<00:01,  3.89s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  36% 0.356283841828826/1 [00:17<00:30, 48.03s/it]
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 19.8 MB   | :  37% 0.3732242030446978/1 [00:17<00:14, 22.60s/it]
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | :  76% 0.7640580587754394/1 [00:17<00:00,  3.33s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  36% 0.35914085100741566/1 [00:17<00:28, 43.72s/it]
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 19.8 MB   | :  49% 0.4944826993925531/1 [00:17<00:07, 14.12s/it]
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | :  85% 0.8480123900529335/1 [00:17<00:00,  2.56s/it]
#
#
#
#
#
#
# libcusolver-11.6.1.9 | 83.5 MB   | :  82% 0.8181388060243204/1 [00:17<00:00,  3.03s/it]
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 19.8 MB   | :  66% 0.6637721585794941/1 [00:17<00:02,  8.21s/it]
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  36% 0.3614970298917506/1 [00:17<00:30, 47.52s/it]
#
#
#
#
#
#
# libcusolver-11.6.1.9 | 83.5 MB   | :  85% 0.8520173518697568/1 [00:17<00:00,  3.10s/it]
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  36% 0.36367108866908376/1 [00:17<00:32, 50.71s/it]
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | :  99% 0.9860951717593383/1 [00:17<00:00,  2.14s/it]
#
#
#
#
#
#
# libcusolver-11.6.1.9 | 83.5 MB   | :  88% 0.8849600262829986/1 [00:17<00:00,  3.13s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | : 100% 1.0/1 [00:17<00:00,  4.22s/it]
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 19.8 MB   | :  95% 0.9519579356140075/1 [00:17<00:00,  3.99s/it]
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  37% 0.36569717485947806/1 [00:18<00:32, 51.08s/it]
#
#
#
#
#
#
# libcusolver-11.6.1.9 | 83.5 MB   | :  93% 0.9253896721537955/1 [00:18<00:00,  3.05s/it]
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  37% 0.36770049603649707/1 [00:18<00:33, 52.88s/it]
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  37% 0.3696241396667029/1 [00:18<00:34, 54.82s/it]
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  37% 0.37188925849753696/1 [00:18<00:32, 51.49s/it]
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  37% 0.3745186175423744/1 [00:18<00:30, 48.45s/it]
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.4.12 | 17.4 MB   | :  91% 0.9117771643884542/1 [00:18<00:00,  8.37s/it]
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 19.8 MB   | : 100% 1.0/1 [00:18<00:00,  3.99s/it]
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  38% 0.37690894394677216/1 [00:18<00:29, 46.71s/it]
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  38% 0.37951553797823445/1 [00:18<00:27, 44.39s/it]
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  38% 0.38214489702307197/1 [00:18<00:26, 42.58s/it]
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | : 100% 1.0/1 [00:18<00:00,  2.14s/it]
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  39% 0.3853206163889147/1 [00:18<00:23, 38.67s/it]
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.4.12 | 17.4 MB   | : 100% 1.0/1 [00:18<00:00,  8.37s/it]
#
#
#
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 17.2 MB   | :  86% 0.8568510065067749/1 [00:18<00:01,  8.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  39% 0.387927210420377/1 [00:18<00:24, 39.74s/it]
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.20.0   | 13.2 MB   | :   0% 0.0011854185130044767/1 [00:19<4:27:13, 16052.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  39% 0.3904655094117136/1 [00:19<00:27, 44.51s/it]
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.20.0   | 13.2 MB   | :  22% 0.22167326193183715/1 [00:19<00:47, 60.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  39% 0.39277615826929807/1 [00:19<00:27, 46.06s/it]
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.20.0   | 13.2 MB   | :  46% 0.457571546019728/1 [00:19<00:13, 24.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# sympy-1.13.3         | 11.2 MB   | :  92% 0.9186063387242462/1 [00:19<00:00, 10.09s/it]
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  40% 0.3974316035045299/1 [00:19<00:27, 46.23s/it]
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.20.0   | 13.2 MB   | :  92% 0.915143092039456/1 [00:19<00:00,  8.36s/it]
#
#
#
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 17.2 MB   | : 100% 1.0/1 [00:19<00:00,  8.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# sympy-1.13.3         | 11.2 MB   | : 100% 1.0/1 [00:19<00:00, 10.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-base-1.24.3    | 6.2 MB    | :   0% 0.002510203062312911/1 [00:19<2:09:38, 7797.65s/it]
#
#
# pytorch-2.4.1        | 1.34 GB   | :  40% 0.39963980980192587/1 [00:19<00:30, 51.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.4.1     | 6.2 MB    | :   0% 0.0025063243233237925/1 [00:19<2:10:03, 7823.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  40% 0.4021439612731997/1 [00:19<00:28, 48.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.4.1     | 6.2 MB    | :  54% 0.543872378161263/1 [00:19<00:11, 25.46s/it]
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.20.0   | 13.2 MB   | : 100% 1.0/1 [00:19<00:00,  8.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    | :   0% 0.0035718910660429226/1 [00:19<1:31:54, 5533.77s/it]
#
#
#
#
#
#
# libcusolver-11.6.1.9 | 83.5 MB   | : 100% 1.0/1 [00:19<00:00, 15.91s/it]
#
#
#
#
#
#
# libcusolver-11.6.1.9 | 83.5 MB   | : 100% 1.0/1 [00:19<00:00, 15.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.1         | 2.7 MB    | :   1% 0.005692575226665879/1 [00:19<57:47, 3487.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.1         | 2.7 MB    | :   7% 0.07400347794665643/1 [00:21<03:13, 209.38s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    | :   3% 0.02857512852834338/1 [00:21<08:55, 551.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.1         | 2.7 MB    | :  14% 0.14231438066664698/1 [00:21<01:17, 89.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    | :   8% 0.07500971238690138/1 [00:21<02:31, 163.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.1         | 2.7 MB    | :  21% 0.21062528338663752/1 [00:21<00:39, 50.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    | :  12% 0.11787240517941645/1 [00:21<01:15, 85.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.1         | 2.7 MB    | :  28% 0.27893618610662807/1 [00:21<00:22, 31.06s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    | :  16% 0.16073509797193153/1 [00:21<00:43, 51.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.1         | 2.7 MB    | :  35% 0.34724708882661864/1 [00:21<00:13, 20.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  40% 0.4042611075170948/1 [00:21<02:45, 277.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.1         | 2.7 MB    | :  42% 0.42125056677327505/1 [00:21<00:07, 13.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    | :  25% 0.24646048355696168/1 [00:21<00:17, 22.88s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.1         | 2.7 MB    | :  49% 0.4895614694932656/1 [00:21<00:04,  9.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    | :  29% 0.28932317634947674/1 [00:21<00:11, 16.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.1         | 2.7 MB    | :  56% 0.5578723722132561/1 [00:21<00:03,  7.32s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  41% 0.4057863634132343/1 [00:21<02:36, 262.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.1         | 2.7 MB    | : 100% 1.0/1 [00:21<00:00,  2.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.1         | 2.7 MB    | : 100% 1.0/1 [00:21<00:00,  2.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  41% 0.4078921271504419/1 [00:22<01:57, 198.41s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-12.3.1.117 | 2.6 MB    | :   1% 0.006123262042278314/1 [00:21<59:27, 3589.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    | : 100% 1.0/1 [00:22<00:00,  1.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    | : 100% 1.0/1 [00:22<00:00,  1.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  41% 0.41035074859496523/1 [00:22<01:25, 145.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-12.3.1.117 | 2.6 MB    | : 100% 1.0/1 [00:22<00:00, 15.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | :  72% 0.7201484331115992/1 [00:29<00:04, 15.63s/it]
#
#
#
# pytorch-2.4.1        | 1.34 GB   | : 100% 0.9973580009816105/1 [00:36<00:00, 16.28s/it]
# libcublas-12.4.5.8   | 247.6 MB  | : 100% 1.0/1 [00:40<00:00,  4.61s/it]
#
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  | : 100% 1.0/1 [00:43<00:00,  3.24s/it]
#
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | : 100% 1.0/1 [00:47<00:00,  4.22s/it]
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 19.8 MB   | : 100% 1.0/1 [00:48<00:00,  3.99s/it]
#
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | : 100% 1.0/1 [00:49<00:00,  2.14s/it]
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.4.12 | 17.4 MB   | : 100% 1.0/1 [00:49<00:00,  8.37s/it]
#
#
#
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 17.2 MB   | : 100% 1.0/1 [00:50<00:00,  8.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.4.1        | 1.34 GB   | : 100% 1.0/1 [00:56<00:00, 16.28s/it]
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.20.0   | 13.2 MB   | : 100% 1.0/1 [00:58<00:00,  8.36s/it]
#
#
#
#
#
#
# libcusolver-11.6.1.9 | 83.5 MB   | : 100% 1.0/1 [00:59<00:00, 15.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.1         | 2.7 MB    | : 100% 1.0/1 [01:00<00:00,  2.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-base-1.24.3    | 6.2 MB    | : 100% 1.0/1 [01:01<00:00, 22.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    | : 100% 1.0/1 [01:01<00:00,  1.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.4.1     | 6.2 MB    | : 100% 1.0/1 [01:02<00:00, 25.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-12.3.1.117 | 2.6 MB    | : 100% 1.0/1 [01:02<00:00, 15.55s/it]
#
# pytorch-2.4.1        | 1.34 GB   | : 100% 1.0/1 [04:10<00:00, 16.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
# !conda run -n myenv pip install torchmetrics==0.3.2
# Out:
# Collecting torchmetrics==0.3.2
#   Downloading torchmetrics-0.3.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/envs/myenv/lib/python3.8/site-packages (from torchmetrics==0.3.2) (2.4.1)
# Requirement already satisfied: packaging in /usr/local/envs/myenv/lib/python3.8/site-packages (from torchmetrics==0.3.2) (24.2)
# Requirement already satisfied: filelock in /usr/local/envs/myenv/lib/python3.8/site-packages (from torch>=1.3.1->torchmetrics==0.3.2) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/envs/myenv/lib/python3.8/site-packages (from torch>=1.3.1->torchmetrics==0.3.2) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/envs/myenv/lib/python3.8/site-packages (from torch>=1.3.1->torchmetrics==0.3.2) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/envs/myenv/lib/python3.8/site-packages (from torch>=1.3.1->torchmetrics==0.3.2) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/envs/myenv/lib/python3.8/site-packages (from torch>=1.3.1->torchmetrics==0.3.2) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/envs/myenv/lib/python3.8/site-packages (from torch>=1.3.1->torchmetrics==0.3.2) (2025.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/envs/myenv/lib/python3.8/site-packages (from jinja2->torch>=1.3.1->torchmetrics==0.3.2) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/envs/myenv/lib/python3.8/site-packages (from sympy->torch>=1.3.1->torchmetrics==0.3.2) (1.3.0)
# Downloading torchmetrics-0.3.2-py3-none-any.whl (274 kB)
# Installing collected packages: torchmetrics
#   Attempting uninstall: torchmetrics
#     Found existing installation: torchmetrics 1.5.2
#     Uninstalling torchmetrics-1.5.2:
#       Successfully uninstalled torchmetrics-1.5.2
# Successfully installed torchmetrics-0.3.2

# %%
# !conda run -n myenv pip install Pillow==8.2.0
# Out:
# Collecting Pillow==8.2.0
#   Downloading Pillow-8.2.0-cp38-cp38-manylinux1_x86_64.whl.metadata (7.1 kB)
# Downloading Pillow-8.2.0-cp38-cp38-manylinux1_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 9.9 MB/s eta 0:00:00
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 10.4.0
#     Uninstalling pillow-10.4.0:
#       Successfully uninstalled pillow-10.4.0
# Successfully installed Pillow-8.2.0

# %%
# !conda run -n myenv python /content/drive/MyDrive/STPM_12_04_2024/STPM_anomaly_detection/train.py \
--phase train \
--dataset_path /content/drive/MyDrive/STPM_12_04_2024/STPM_anomaly_detection/mvtec_anomaly_detection \
--category wood \
--project_path /content/drive/MyDrive/STPM_12_04_2024/STPM_anomaly_detection
# Out:
# Training: 0it [00:00, ?it/s]
# Training:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 3/3 [00:01<00:00,  2.20it/s]
# Epoch 0: 100%|██████████| 3/3 [00:01<00:00,  2.20it/s, loss=34.5, v_num=8]
# Epoch 0:   0%|          | 0/3 [00:00<?, ?it/s, loss=34.5, v_num=8]
# Epoch 1:   0%|          | 0/3 [00:00<?, ?it/s, loss=34.5, v_num=8]
# Epoch 1: 100%|██████████| 3/3 [00:01<00:00,  2.62it/s, loss=34.5, v_num=8]
# Epoch 1: 100%|██████████| 3/3 [00:01<00:00,  2.62it/s, loss=27.4, v_num=8]
# Epoch 1:   0%|          | 0/3 [00:00<?, ?it/s, loss=27.4, v_num=8]
# Epoch 2:   0%|          | 0/3 [00:00<?, ?it/s, loss=27.4, v_num=8]
# Epoch 2: 100%|██████████| 3/3 [00:01<00:00,  2.62it/s, loss=27.4, v_num=8]
# Epoch 2: 100%|██████████| 3/3 [00:01<00:00,  2.62it/s, loss=24.2, v_num=8]
# Epoch 2:   0%|          | 0/3 [00:00<?, ?it/s, loss=24.2, v_num=8]
# Epoch 3:   0%|          | 0/3 [00:00<?, ?it/s, loss=24.2, v_num=8]
# Epoch 3: 100%|██████████| 3/3 [00:01<00:00,  2.71it/s, loss=24.2, v_num=8]
# Epoch 3: 100%|██████████| 3/3 [00:01<00:00,  2.71it/s, loss=22.3, v_num=8]
# Epoch 3:   0%|          | 0/3 [00:00<?, ?it/s, loss=22.3, v_num=8]
# Epoch 4:   0%|          | 0/3 [00:00<?, ?it/s, loss=22.3, v_num=8]
# Epoch 4: 100%|██████████| 3/3 [00:01<00:00,  2.85it/s, loss=22.3, v_num=8]
# Epoch 4: 100%|██████████| 3/3 [00:01<00:00,  2.84it/s, loss=21, v_num=8]
# Epoch 4:   0%|          | 0/3 [00:00<?, ?it/s, loss=21, v_num=8]
# Epoch 5:   0%|          | 0/3 [00:00<?, ?it/s, loss=21, v_num=8]
# Epoch 5: 100%|██████████| 3/3 [00:01<00:00,  2.85it/s, loss=21, v_num=8]
# Epoch 5: 100%|██████████| 3/3 [00:01<00:00,  2.85it/s, loss=19.9, v_num=8]
# Epoch 5:   0%|          | 0/3 [00:00<?, ?it/s, loss=19.9, v_num=8]
# Epoch 6:   0%|          | 0/3 [00:00<?, ?it/s, loss=19.9, v_num=8]
# Epoch 6: 100%|██████████| 3/3 [00:01<00:00,  2.42it/s, loss=19.9, v_num=8]
# Epoch 6: 100%|██████████| 3/3 [00:01<00:00,  2.42it/s, loss=17.2, v_num=8]
# Epoch 6:   0%|          | 0/3 [00:00<?, ?it/s, loss=17.2, v_num=8]
# Epoch 7:   0%|          | 0/3 [00:00<?, ?it/s, loss=17.2, v_num=8]
# Epoch 7: 100%|██████████| 3/3 [00:01<00:00,  2.53it/s, loss=17.2, v_num=8]
# Epoch 7: 100%|██████████| 3/3 [00:01<00:00,  2.53it/s, loss=15.5, v_num=8]
# Epoch 7:   0%|          | 0/3 [00:00<?, ?it/s, loss=15.5, v_num=8]
# Epoch 8:   0%|          | 0/3 [00:00<?, ?it/s, loss=15.5, v_num=8]
# Epoch 8: 100%|██████████| 3/3 [00:01<00:00,  2.63it/s, loss=15.5, v_num=8]
# Epoch 8: 100%|██████████| 3/3 [00:01<00:00,  2.63it/s, loss=14.6, v_num=8]
# Epoch 8:   0%|          | 0/3 [00:00<?, ?it/s, loss=14.6, v_num=8]
# Epoch 9:   0%|          | 0/3 [00:00<?, ?it/s, loss=14.6, v_num=8]
# Epoch 9: 100%|██████████| 3/3 [00:01<00:00,  2.33it/s, loss=14.6, v_num=8]
# Epoch 9: 100%|██████████| 3/3 [00:01<00:00,  2.33it/s, loss=14, v_num=8]
# Epoch 9:   0%|          | 0/3 [00:00<?, ?it/s, loss=14, v_num=8]
# Epoch 10:   0%|          | 0/3 [00:00<?, ?it/s, loss=14, v_num=8]
# Epoch 10: 100%|██████████| 3/3 [00:01<00:00,  2.65it/s, loss=14, v_num=8]
# Epoch 10: 100%|██████████| 3/3 [00:01<00:00,  2.64it/s, loss=13.5, v_num=8]
# Epoch 10:   0%|          | 0/3 [00:00<?, ?it/s, loss=13.5, v_num=8]
# Epoch 11:   0%|          | 0/3 [00:00<?, ?it/s, loss=13.5, v_num=8]
# Epoch 11: 100%|██████████| 3/3 [00:00<00:00,  3.31it/s, loss=13.5, v_num=8]
# Epoch 11: 100%|██████████| 3/3 [00:00<00:00,  3.31it/s, loss=13.1, v_num=8]
# Epoch 11:   0%|          | 0/3 [00:00<?, ?it/s, loss=13.1, v_num=8]
# Epoch 12:   0%|          | 0/3 [00:00<?, ?it/s, loss=13.1, v_num=8]
# Epoch 12: 100%|██████████| 3/3 [00:01<00:00,  2.62it/s, loss=13.1, v_num=8]
# Epoch 12: 100%|██████████| 3/3 [00:01<00:00,  2.62it/s, loss=12.8, v_num=8]
# Epoch 12:   0%|          | 0/3 [00:00<?, ?it/s, loss=12.8, v_num=8]
# Epoch 13:   0%|          | 0/3 [00:00<?, ?it/s, loss=12.8, v_num=8]
# Epoch 13: 100%|██████████| 3/3 [00:01<00:00,  2.53it/s, loss=12.8, v_num=8]
# Epoch 13: 100%|██████████| 3/3 [00:01<00:00,  2.53it/s, loss=12.5, v_num=8]
# Epoch 13:   0%|          | 0/3 [00:00<?, ?it/s, loss=12.5, v_num=8]
# Epoch 14:   0%|          | 0/3 [00:00<?, ?it/s, loss=12.5, v_num=8]
# Epoch 14: 100%|██████████| 3/3 [00:01<00:00,  2.36it/s, loss=12.5, v_num=8]
# Epoch 14: 100%|██████████| 3/3 [00:01<00:00,  2.36it/s, loss=12.3, v_num=8]
# Epoch 14:   0%|          | 0/3 [00:00<?, ?it/s, loss=12.3, v_num=8]
# Epoch 15:   0%|          | 0/3 [00:00<?, ?it/s, loss=12.3, v_num=8]
# Epoch 15: 100%|██████████| 3/3 [00:01<00:00,  2.65it/s, loss=12.3, v_num=8]
# Epoch 15: 100%|██████████| 3/3 [00:01<00:00,  2.64it/s, loss=12.1, v_num=8]
# Epoch 15:   0%|          | 0/3 [00:00<?, ?it/s, loss=12.1, v_num=8]
# Epoch 16:   0%|          | 0/3 [00:00<?, ?it/s, loss=12.1, v_num=8]
# Epoch 16: 100%|██████████| 3/3 [00:01<00:00,  2.67it/s, loss=12.1, v_num=8]
# Epoch 16: 100%|██████████| 3/3 [00:01<00:00,  2.66it/s, loss=11.9, v_num=8]
# Epoch 16:   0%|          | 0/3 [00:00<?, ?it/s, loss=11.9, v_num=8]
# Epoch 17:   0%|          | 0/3 [00:00<?, ?it/s, loss=11.9, v_num=8]
# Epoch 17: 100%|██████████| 3/3 [00:01<00:00,  2.60it/s, loss=11.9, v_num=8]
# Epoch 17: 100%|██████████| 3/3 [00:01<00:00,  2.60it/s, loss=11.7, v_num=8]
# Epoch 17:   0%|          | 0/3 [00:00<?, ?it/s, loss=11.7, v_num=8]
# Epoch 18:   0%|          | 0/3 [00:00<?, ?it/s, loss=11.7, v_num=8]
# Epoch 18: 100%|██████████| 3/3 [00:01<00:00,  2.63it/s, loss=11.7, v_num=8]
# Epoch 18: 100%|██████████| 3/3 [00:01<00:00,  2.63it/s, loss=11.5, v_num=8]
# Epoch 18:   0%|          | 0/3 [00:00<?, ?it/s, loss=11.5, v_num=8]
# Epoch 19:   0%|          | 0/3 [00:00<?, ?it/s, loss=11.5, v_num=8]
# Epoch 19: 100%|██████████| 3/3 [00:01<00:00,  2.55it/s, loss=11.5, v_num=8]
# Epoch 19: 100%|██████████| 3/3 [00:01<00:00,  2.55it/s, loss=11.4, v_num=8]
# Epoch 19:   0%|          | 0/3 [00:00<?, ?it/s, loss=11.4, v_num=8]
# Epoch 20:   0%|          | 0/3 [00:00<?, ?it/s, loss=11.4, v_num=8]
# Epoch 20: 100%|██████████| 3/3 [00:01<00:00,  2.66it/s, loss=11.4, v_num=8]
# Epoch 20: 100%|██████████| 3/3 [00:01<00:00,  2.66it/s, loss=11.2, v_num=8]
# Epoch 20:   0%|          | 0/3 [00:00<?, ?it/s, loss=11.2, v_num=8]
# Epoch 21:   0%|          | 0/3 [00:00<?, ?it/s, loss=11.2, v_num=8]
# Epoch 21: 100%|██████████| 3/3 [00:01<00:00,  2.45it/s, loss=11.2, v_num=8]
# Epoch 21: 100%|██████████| 3/3 [00:01<00:00,  2.44it/s, loss=11, v_num=8]
# Epoch 21:   0%|          | 0/3 [00:00<?, ?it/s, loss=11, v_num=8]
# Epoch 22:   0%|          | 0/3 [00:00<?, ?it/s, loss=11, v_num=8]
# Epoch 22: 100%|██████████| 3/3 [00:01<00:00,  2.43it/s, loss=11, v_num=8]
# Epoch 22: 100%|██████████| 3/3 [00:01<00:00,  2.42it/s, loss=10.9, v_num=8]
# Epoch 22:   0%|          | 0/3 [00:00<?, ?it/s, loss=10.9, v_num=8]
# Epoch 23:   0%|          | 0/3 [00:00<?, ?it/s, loss=10.9, v_num=8]
# Epoch 23: 100%|██████████| 3/3 [00:01<00:00,  2.48it/s, loss=10.9, v_num=8]
# Epoch 23: 100%|██████████| 3/3 [00:01<00:00,  2.48it/s, loss=10.8, v_num=8]
# Epoch 23:   0%|          | 0/3 [00:00<?, ?it/s, loss=10.8, v_num=8]
# Epoch 24:   0%|          | 0/3 [00:00<?, ?it/s, loss=10.8, v_num=8]
# Epoch 24: 100%|██████████| 3/3 [00:01<00:00,  2.66it/s, loss=10.8, v_num=8]
# Epoch 24: 100%|██████████| 3/3 [00:01<00:00,  2.66it/s, loss=10.6, v_num=8]
# Epoch 24:   0%|          | 0/3 [00:00<?, ?it/s, loss=10.6, v_num=8]
# Epoch 25:   0%|          | 0/3 [00:00<?, ?it/s, loss=10.6, v_num=8]
# Epoch 25: 100%|██████████| 3/3 [00:01<00:00,  2.61it/s, loss=10.6, v_num=8]
# Epoch 25: 100%|██████████| 3/3 [00:01<00:00,  2.61it/s, loss=10.5, v_num=8]
# Epoch 25:   0%|          | 0/3 [00:00<?, ?it/s, loss=10.5, v_num=8]
# Epoch 26:   0%|          | 0/3 [00:00<?, ?it/s, loss=10.5, v_num=8]
# Epoch 26: 100%|██████████| 3/3 [00:01<00:00,  2.75it/s, loss=10.5, v_num=8]
# Epoch 26: 100%|██████████| 3/3 [00:01<00:00,  2.75it/s, loss=10.4, v_num=8]
# Epoch 26:   0%|          | 0/3 [00:00<?, ?it/s, loss=10.4, v_num=8]
# Epoch 27:   0%|          | 0/3 [00:00<?, ?it/s, loss=10.4, v_num=8]
# Epoch 27: 100%|██████████| 3/3 [00:00<00:00,  3.91it/s, loss=10.4, v_num=8]
# Epoch 27: 100%|██████████| 3/3 [00:00<00:00,  3.91it/s, loss=10.3, v_num=8]
# Epoch 27:   0%|          | 0/3 [00:00<?, ?it/s, loss=10.3, v_num=8]
# Epoch 28:   0%|          | 0/3 [00:00<?, ?it/s, loss=10.3, v_num=8]
# Epoch 28: 100%|██████████| 3/3 [00:01<00:00,  2.56it/s, loss=10.3, v_num=8]
# Epoch 28: 100%|██████████| 3/3 [00:01<00:00,  2.56it/s, loss=10.2, v_num=8]
# Epoch 28:   0%|          | 0/3 [00:00<?, ?it/s, loss=10.2, v_num=8]
# Epoch 29:   0%|          | 0/3 [00:00<?, ?it/s, loss=10.2, v_num=8]
# Epoch 29: 100%|██████████| 3/3 [00:01<00:00,  2.73it/s, loss=10.2, v_num=8]
# Epoch 29: 100%|██████████| 3/3 [00:01<00:00,  2.73it/s, loss=10.1, v_num=8]
# Epoch 29:   0%|          | 0/3 [00:00<?, ?it/s, loss=10.1, v_num=8]
# Epoch 30:   0%|          | 0/3 [00:00<?, ?it/s, loss=10.1, v_num=8]
# Epoch 30: 100%|██████████| 3/3 [00:01<00:00,  2.44it/s, loss=10.1, v_num=8]
# Epoch 30: 100%|██████████| 3/3 [00:01<00:00,  2.44it/s, loss=10.1, v_num=8]
# Epoch 30:   0%|          | 0/3 [00:00<?, ?it/s, loss=10.1, v_num=8]
# Epoch 31:   0%|          | 0/3 [00:00<?, ?it/s, loss=10.1, v_num=8]
# Epoch 31: 100%|██████████| 3/3 [00:01<00:00,  2.65it/s, loss=10.1, v_num=8]
# Epoch 31: 100%|██████████| 3/3 [00:01<00:00,  2.65it/s, loss=9.98, v_num=8]
# Epoch 31:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.98, v_num=8]
# Epoch 32:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.98, v_num=8]
# Epoch 32: 100%|██████████| 3/3 [00:00<00:00,  3.33it/s, loss=9.98, v_num=8]
# Epoch 32: 100%|██████████| 3/3 [00:00<00:00,  3.33it/s, loss=9.94, v_num=8]
# Epoch 32:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.94, v_num=8]
# Epoch 33:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.94, v_num=8]
# Epoch 33: 100%|██████████| 3/3 [00:01<00:00,  2.61it/s, loss=9.94, v_num=8]
# Epoch 33: 100%|██████████| 3/3 [00:01<00:00,  2.61it/s, loss=9.9, v_num=8]
# Epoch 33:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.9, v_num=8]
# Epoch 34:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.9, v_num=8]
# Epoch 34: 100%|██████████| 3/3 [00:01<00:00,  2.61it/s, loss=9.9, v_num=8]
# Epoch 34: 100%|██████████| 3/3 [00:01<00:00,  2.61it/s, loss=9.84, v_num=8]
# Epoch 34:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.84, v_num=8]
# Epoch 35:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.84, v_num=8]
# Epoch 35: 100%|██████████| 3/3 [00:01<00:00,  2.63it/s, loss=9.84, v_num=8]
# Epoch 35: 100%|██████████| 3/3 [00:01<00:00,  2.62it/s, loss=9.79, v_num=8]
# Epoch 35:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.79, v_num=8]
# Epoch 36:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.79, v_num=8]
# Epoch 36: 100%|██████████| 3/3 [00:01<00:00,  2.58it/s, loss=9.79, v_num=8]
# Epoch 36: 100%|██████████| 3/3 [00:01<00:00,  2.58it/s, loss=9.72, v_num=8]
# Epoch 36:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.72, v_num=8]
# Epoch 37:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.72, v_num=8]
# Epoch 37: 100%|██████████| 3/3 [00:01<00:00,  2.63it/s, loss=9.72, v_num=8]
# Epoch 37: 100%|██████████| 3/3 [00:01<00:00,  2.63it/s, loss=9.69, v_num=8]
# Epoch 37:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.69, v_num=8]
# Epoch 38:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.69, v_num=8]
# Epoch 38: 100%|██████████| 3/3 [00:01<00:00,  2.42it/s, loss=9.69, v_num=8]
# Epoch 38: 100%|██████████| 3/3 [00:01<00:00,  2.42it/s, loss=9.63, v_num=8]
# Epoch 38:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.63, v_num=8]
# Epoch 39:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.63, v_num=8]
# Epoch 39: 100%|██████████| 3/3 [00:01<00:00,  2.44it/s, loss=9.63, v_num=8]
# Epoch 39: 100%|██████████| 3/3 [00:01<00:00,  2.44it/s, loss=9.56, v_num=8]
# Epoch 39:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.56, v_num=8]
# Epoch 40:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.56, v_num=8]
# Epoch 40: 100%|██████████| 3/3 [00:00<00:00,  3.87it/s, loss=9.56, v_num=8]
# Epoch 40: 100%|██████████| 3/3 [00:00<00:00,  3.87it/s, loss=9.5, v_num=8]
# Epoch 40:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.5, v_num=8]
# Epoch 41:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.5, v_num=8]
# Epoch 41: 100%|██████████| 3/3 [00:00<00:00,  3.35it/s, loss=9.5, v_num=8]
# Epoch 41: 100%|██████████| 3/3 [00:00<00:00,  3.35it/s, loss=9.44, v_num=8]
# Epoch 41:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.44, v_num=8]
# Epoch 42:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.44, v_num=8]
# Epoch 42: 100%|██████████| 3/3 [00:01<00:00,  2.60it/s, loss=9.44, v_num=8]
# Epoch 42: 100%|██████████| 3/3 [00:01<00:00,  2.60it/s, loss=9.38, v_num=8]
# Epoch 42:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.38, v_num=8]
# Epoch 43:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.38, v_num=8]
# Epoch 43: 100%|██████████| 3/3 [00:01<00:00,  2.58it/s, loss=9.38, v_num=8]
# Epoch 43: 100%|██████████| 3/3 [00:01<00:00,  2.58it/s, loss=9.31, v_num=8]
# Epoch 43:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.31, v_num=8]
# Epoch 44:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.31, v_num=8]
# Epoch 44: 100%|██████████| 3/3 [00:01<00:00,  2.74it/s, loss=9.31, v_num=8]
# Epoch 44: 100%|██████████| 3/3 [00:01<00:00,  2.74it/s, loss=9.27, v_num=8]
# Epoch 44:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.27, v_num=8]
# Epoch 45:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.27, v_num=8]
# Epoch 45: 100%|██████████| 3/3 [00:01<00:00,  2.44it/s, loss=9.27, v_num=8]
# Epoch 45: 100%|██████████| 3/3 [00:01<00:00,  2.44it/s, loss=9.21, v_num=8]
# Epoch 45:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.21, v_num=8]
# Epoch 46:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.21, v_num=8]
# Epoch 46: 100%|██████████| 3/3 [00:01<00:00,  2.60it/s, loss=9.21, v_num=8]
# Epoch 46: 100%|██████████| 3/3 [00:01<00:00,  2.60it/s, loss=9.15, v_num=8]
# Epoch 46:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.15, v_num=8]
# Epoch 47:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.15, v_num=8]
# Epoch 47: 100%|██████████| 3/3 [00:01<00:00,  2.34it/s, loss=9.15, v_num=8]
# Epoch 47: 100%|██████████| 3/3 [00:01<00:00,  2.34it/s, loss=9.1, v_num=8]
# Epoch 47:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.1, v_num=8]
# Epoch 48:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.1, v_num=8]
# Epoch 48: 100%|██████████| 3/3 [00:01<00:00,  2.51it/s, loss=9.1, v_num=8]
# Epoch 48: 100%|██████████| 3/3 [00:01<00:00,  2.51it/s, loss=9.08, v_num=8]
# Epoch 48:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.08, v_num=8]
# Epoch 49:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.08, v_num=8]
# Epoch 49: 100%|██████████| 3/3 [00:00<00:00,  3.92it/s, loss=9.08, v_num=8]
# Epoch 49: 100%|██████████| 3/3 [00:00<00:00,  3.91it/s, loss=9.02, v_num=8]
# Epoch 49:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.02, v_num=8]
# Epoch 50:   0%|          | 0/3 [00:00<?, ?it/s, loss=9.02, v_num=8]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00,  3.17it/s, loss=9.02, v_num=8]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00,  3.17it/s, loss=8.98, v_num=8]
# Epoch 50:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.98, v_num=8]
# Epoch 51:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.98, v_num=8]
# Epoch 51: 100%|██████████| 3/3 [00:01<00:00,  2.60it/s, loss=8.98, v_num=8]
# Epoch 51: 100%|██████████| 3/3 [00:01<00:00,  2.60it/s, loss=8.96, v_num=8]
# Epoch 51:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.96, v_num=8]
# Epoch 52:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.96, v_num=8]
# Epoch 52: 100%|██████████| 3/3 [00:01<00:00,  2.63it/s, loss=8.96, v_num=8]
# Epoch 52: 100%|██████████| 3/3 [00:01<00:00,  2.63it/s, loss=8.9, v_num=8]
# Epoch 52:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.9, v_num=8]
# Epoch 53:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.9, v_num=8]
# Epoch 53: 100%|██████████| 3/3 [00:01<00:00,  2.73it/s, loss=8.9, v_num=8]
# Epoch 53: 100%|██████████| 3/3 [00:01<00:00,  2.72it/s, loss=8.85, v_num=8]
# Epoch 53:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.85, v_num=8]
# Epoch 54:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.85, v_num=8]
# Epoch 54: 100%|██████████| 3/3 [00:01<00:00,  2.45it/s, loss=8.85, v_num=8]
# Epoch 54: 100%|██████████| 3/3 [00:01<00:00,  2.44it/s, loss=8.79, v_num=8]
# Epoch 54:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.79, v_num=8]
# Epoch 55:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.79, v_num=8]
# Epoch 55: 100%|██████████| 3/3 [00:01<00:00,  2.47it/s, loss=8.79, v_num=8]
# Epoch 55: 100%|██████████| 3/3 [00:01<00:00,  2.47it/s, loss=8.74, v_num=8]
# Epoch 55:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.74, v_num=8]
# Epoch 56:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.74, v_num=8]
# Epoch 56: 100%|██████████| 3/3 [00:01<00:00,  2.41it/s, loss=8.74, v_num=8]
# Epoch 56: 100%|██████████| 3/3 [00:01<00:00,  2.41it/s, loss=8.67, v_num=8]
# Epoch 56:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.67, v_num=8]
# Epoch 57:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.67, v_num=8]
# Epoch 57: 100%|██████████| 3/3 [00:01<00:00,  2.92it/s, loss=8.67, v_num=8]
# Epoch 57: 100%|██████████| 3/3 [00:01<00:00,  2.91it/s, loss=8.62, v_num=8]
# Epoch 57:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.62, v_num=8]
# Epoch 58:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.62, v_num=8]
# Epoch 58: 100%|██████████| 3/3 [00:00<00:00,  3.76it/s, loss=8.62, v_num=8]
# Epoch 58: 100%|██████████| 3/3 [00:00<00:00,  3.76it/s, loss=8.58, v_num=8]
# Epoch 58:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.58, v_num=8]
# Epoch 59:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.58, v_num=8]
# Epoch 59: 100%|██████████| 3/3 [00:00<00:00,  3.21it/s, loss=8.58, v_num=8]
# Epoch 59: 100%|██████████| 3/3 [00:00<00:00,  3.21it/s, loss=8.55, v_num=8]
# Epoch 59:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.55, v_num=8]
# Epoch 60:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.55, v_num=8]
# Epoch 60: 100%|██████████| 3/3 [00:01<00:00,  2.70it/s, loss=8.55, v_num=8]
# Epoch 60: 100%|██████████| 3/3 [00:01<00:00,  2.70it/s, loss=8.5, v_num=8]
# Epoch 60:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.5, v_num=8]
# Epoch 61:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.5, v_num=8]
# Epoch 61: 100%|██████████| 3/3 [00:01<00:00,  2.55it/s, loss=8.5, v_num=8]
# Epoch 61: 100%|██████████| 3/3 [00:01<00:00,  2.55it/s, loss=8.48, v_num=8]
# Epoch 61:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.48, v_num=8]
# Epoch 62:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.48, v_num=8]
# Epoch 62: 100%|██████████| 3/3 [00:01<00:00,  2.81it/s, loss=8.48, v_num=8]
# Epoch 62: 100%|██████████| 3/3 [00:01<00:00,  2.81it/s, loss=8.45, v_num=8]
# Epoch 62:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.45, v_num=8]
# Epoch 63:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.45, v_num=8]
# Epoch 63: 100%|██████████| 3/3 [00:01<00:00,  2.46it/s, loss=8.45, v_num=8]
# Epoch 63: 100%|██████████| 3/3 [00:01<00:00,  2.46it/s, loss=8.43, v_num=8]
# Epoch 63:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.43, v_num=8]
# Epoch 64:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.43, v_num=8]
# Epoch 64: 100%|██████████| 3/3 [00:01<00:00,  2.39it/s, loss=8.43, v_num=8]
# Epoch 64: 100%|██████████| 3/3 [00:01<00:00,  2.38it/s, loss=8.42, v_num=8]
# Epoch 64:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.42, v_num=8]
# Epoch 65:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.42, v_num=8]
# Epoch 65: 100%|██████████| 3/3 [00:01<00:00,  2.48it/s, loss=8.42, v_num=8]
# Epoch 65: 100%|██████████| 3/3 [00:01<00:00,  2.48it/s, loss=8.39, v_num=8]
# Epoch 65:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.39, v_num=8]
# Epoch 66:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.39, v_num=8]
# Epoch 66: 100%|██████████| 3/3 [00:01<00:00,  2.78it/s, loss=8.39, v_num=8]
# Epoch 66: 100%|██████████| 3/3 [00:01<00:00,  2.78it/s, loss=8.36, v_num=8]
# Epoch 66:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.36, v_num=8]
# Epoch 67:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.36, v_num=8]
# Epoch 67: 100%|██████████| 3/3 [00:01<00:00,  2.46it/s, loss=8.36, v_num=8]
# Epoch 67: 100%|██████████| 3/3 [00:01<00:00,  2.46it/s, loss=8.33, v_num=8]
# Epoch 67:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.33, v_num=8]
# Epoch 68:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.33, v_num=8]
# Epoch 68: 100%|██████████| 3/3 [00:01<00:00,  2.61it/s, loss=8.33, v_num=8]
# Epoch 68: 100%|██████████| 3/3 [00:01<00:00,  2.61it/s, loss=8.28, v_num=8]
# Epoch 68:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.28, v_num=8]
# Epoch 69:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.28, v_num=8]
# Epoch 69: 100%|██████████| 3/3 [00:01<00:00,  2.85it/s, loss=8.28, v_num=8]
# Epoch 69: 100%|██████████| 3/3 [00:01<00:00,  2.85it/s, loss=8.25, v_num=8]
# Epoch 69:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.25, v_num=8]
# Epoch 70:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.25, v_num=8]
# Epoch 70: 100%|██████████| 3/3 [00:01<00:00,  2.57it/s, loss=8.25, v_num=8]
# Epoch 70: 100%|██████████| 3/3 [00:01<00:00,  2.57it/s, loss=8.21, v_num=8]
# Epoch 70:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.21, v_num=8]
# Epoch 71:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.21, v_num=8]
# Epoch 71: 100%|██████████| 3/3 [00:01<00:00,  2.57it/s, loss=8.21, v_num=8]
# Epoch 71: 100%|██████████| 3/3 [00:01<00:00,  2.57it/s, loss=8.16, v_num=8]
# Epoch 71:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.16, v_num=8]
# Epoch 72:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.16, v_num=8]
# Epoch 72: 100%|██████████| 3/3 [00:01<00:00,  2.51it/s, loss=8.16, v_num=8]
# Epoch 72: 100%|██████████| 3/3 [00:01<00:00,  2.51it/s, loss=8.12, v_num=8]
# Epoch 72:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.12, v_num=8]
# Epoch 73:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.12, v_num=8]
# Epoch 73: 100%|██████████| 3/3 [00:01<00:00,  2.42it/s, loss=8.12, v_num=8]
# Epoch 73: 100%|██████████| 3/3 [00:01<00:00,  2.42it/s, loss=8.05, v_num=8]
# Epoch 73:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.05, v_num=8]
# Epoch 74:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.05, v_num=8]
# Epoch 74: 100%|██████████| 3/3 [00:01<00:00,  2.48it/s, loss=8.05, v_num=8]
# Epoch 74: 100%|██████████| 3/3 [00:01<00:00,  2.48it/s, loss=8.01, v_num=8]
# Epoch 74:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.01, v_num=8]
# Epoch 75:   0%|          | 0/3 [00:00<?, ?it/s, loss=8.01, v_num=8]
# Epoch 75: 100%|██████████| 3/3 [00:00<00:00,  3.89it/s, loss=8.01, v_num=8]
# Epoch 75: 100%|██████████| 3/3 [00:00<00:00,  3.89it/s, loss=7.98, v_num=8]
# Epoch 75:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.98, v_num=8]
# Epoch 76:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.98, v_num=8]
# Epoch 76: 100%|██████████| 3/3 [00:00<00:00,  3.21it/s, loss=7.98, v_num=8]
# Epoch 76: 100%|██████████| 3/3 [00:00<00:00,  3.21it/s, loss=7.93, v_num=8]
# Epoch 76:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.93, v_num=8]
# Epoch 77:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.93, v_num=8]
# Epoch 77: 100%|██████████| 3/3 [00:01<00:00,  2.61it/s, loss=7.93, v_num=8]
# Epoch 77: 100%|██████████| 3/3 [00:01<00:00,  2.61it/s, loss=7.91, v_num=8]
# Epoch 77:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.91, v_num=8]
# Epoch 78:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.91, v_num=8]
# Epoch 78: 100%|██████████| 3/3 [00:01<00:00,  2.63it/s, loss=7.91, v_num=8]
# Epoch 78: 100%|██████████| 3/3 [00:01<00:00,  2.63it/s, loss=7.89, v_num=8]
# Epoch 78:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.89, v_num=8]
# Epoch 79:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.89, v_num=8]
# Epoch 79: 100%|██████████| 3/3 [00:01<00:00,  2.71it/s, loss=7.89, v_num=8]
# Epoch 79: 100%|██████████| 3/3 [00:01<00:00,  2.71it/s, loss=7.89, v_num=8]
# Epoch 79:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.89, v_num=8]
# Epoch 80:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.89, v_num=8]
# Epoch 80: 100%|██████████| 3/3 [00:01<00:00,  2.47it/s, loss=7.89, v_num=8]
# Epoch 80: 100%|██████████| 3/3 [00:01<00:00,  2.47it/s, loss=7.87, v_num=8]
# Epoch 80:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.87, v_num=8]
# Epoch 81:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.87, v_num=8]
# Epoch 81: 100%|██████████| 3/3 [00:01<00:00,  2.36it/s, loss=7.87, v_num=8]
# Epoch 81: 100%|██████████| 3/3 [00:01<00:00,  2.36it/s, loss=7.85, v_num=8]
# Epoch 81:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.85, v_num=8]
# Epoch 82:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.85, v_num=8]
# Epoch 82: 100%|██████████| 3/3 [00:01<00:00,  2.43it/s, loss=7.85, v_num=8]
# Epoch 82: 100%|██████████| 3/3 [00:01<00:00,  2.43it/s, loss=7.84, v_num=8]
# Epoch 82:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.84, v_num=8]
# Epoch 83:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.84, v_num=8]
# Epoch 83: 100%|██████████| 3/3 [00:01<00:00,  2.56it/s, loss=7.84, v_num=8]
# Epoch 83: 100%|██████████| 3/3 [00:01<00:00,  2.56it/s, loss=7.82, v_num=8]
# Epoch 83:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.82, v_num=8]
# Epoch 84:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.82, v_num=8]
# Epoch 84: 100%|██████████| 3/3 [00:01<00:00,  2.69it/s, loss=7.82, v_num=8]
# Epoch 84: 100%|██████████| 3/3 [00:01<00:00,  2.69it/s, loss=7.76, v_num=8]
# Epoch 84:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.76, v_num=8]
# Epoch 85:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.76, v_num=8]
# Epoch 85: 100%|██████████| 3/3 [00:01<00:00,  2.67it/s, loss=7.76, v_num=8]
# Epoch 85: 100%|██████████| 3/3 [00:01<00:00,  2.67it/s, loss=7.73, v_num=8]
# Epoch 85:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.73, v_num=8]
# Epoch 86:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.73, v_num=8]
# Epoch 86: 100%|██████████| 3/3 [00:01<00:00,  2.66it/s, loss=7.73, v_num=8]
# Epoch 86: 100%|██████████| 3/3 [00:01<00:00,  2.66it/s, loss=7.65, v_num=8]
# Epoch 86:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.65, v_num=8]
# Epoch 87:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.65, v_num=8]
# Epoch 87: 100%|██████████| 3/3 [00:01<00:00,  2.58it/s, loss=7.65, v_num=8]
# Epoch 87: 100%|██████████| 3/3 [00:01<00:00,  2.58it/s, loss=7.6, v_num=8]
# Epoch 87:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.6, v_num=8]
# Epoch 88:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.6, v_num=8]
# Epoch 88: 100%|██████████| 3/3 [00:00<00:00,  3.71it/s, loss=7.6, v_num=8]
# Epoch 88: 100%|██████████| 3/3 [00:00<00:00,  3.71it/s, loss=7.54, v_num=8]
# Epoch 88:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.54, v_num=8]
# Epoch 89:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.54, v_num=8]
# Epoch 89: 100%|██████████| 3/3 [00:01<00:00,  2.28it/s, loss=7.54, v_num=8]
# Epoch 89: 100%|██████████| 3/3 [00:01<00:00,  2.27it/s, loss=7.46, v_num=8]
# Epoch 89:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.46, v_num=8]
# Epoch 90:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.46, v_num=8]
# Epoch 90: 100%|██████████| 3/3 [00:01<00:00,  2.36it/s, loss=7.46, v_num=8]
# Epoch 90: 100%|██████████| 3/3 [00:01<00:00,  2.36it/s, loss=7.42, v_num=8]
# Epoch 90:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.42, v_num=8]
# Epoch 91:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.42, v_num=8]
# Epoch 91: 100%|██████████| 3/3 [00:00<00:00,  3.08it/s, loss=7.42, v_num=8]
# Epoch 91: 100%|██████████| 3/3 [00:00<00:00,  3.08it/s, loss=7.34, v_num=8]
# Epoch 91:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.34, v_num=8]
# Epoch 92:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.34, v_num=8]
# Epoch 92: 100%|██████████| 3/3 [00:01<00:00,  2.54it/s, loss=7.34, v_num=8]
# Epoch 92: 100%|██████████| 3/3 [00:01<00:00,  2.54it/s, loss=7.31, v_num=8]
# Epoch 92:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.31, v_num=8]
# Epoch 93:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.31, v_num=8]
# Epoch 93: 100%|██████████| 3/3 [00:01<00:00,  2.58it/s, loss=7.31, v_num=8]
# Epoch 93: 100%|██████████| 3/3 [00:01<00:00,  2.58it/s, loss=7.26, v_num=8]
# Epoch 93:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.26, v_num=8]
# Epoch 94:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.26, v_num=8]
# Epoch 94: 100%|██████████| 3/3 [00:01<00:00,  2.63it/s, loss=7.26, v_num=8]
# Epoch 94: 100%|██████████| 3/3 [00:01<00:00,  2.63it/s, loss=7.24, v_num=8]
# Epoch 94:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.24, v_num=8]
# Epoch 95:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.24, v_num=8]
# Epoch 95: 100%|██████████| 3/3 [00:01<00:00,  2.63it/s, loss=7.24, v_num=8]
# Epoch 95: 100%|██████████| 3/3 [00:01<00:00,  2.63it/s, loss=7.19, v_num=8]
# Epoch 95:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.19, v_num=8]
# Epoch 96:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.19, v_num=8]
# Epoch 96: 100%|██████████| 3/3 [00:01<00:00,  2.60it/s, loss=7.19, v_num=8]
# Epoch 96: 100%|██████████| 3/3 [00:01<00:00,  2.60it/s, loss=7.17, v_num=8]
# Epoch 96:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.17, v_num=8]
# Epoch 97:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.17, v_num=8]
# Epoch 97: 100%|██████████| 3/3 [00:01<00:00,  2.47it/s, loss=7.17, v_num=8]
# Epoch 97: 100%|██████████| 3/3 [00:01<00:00,  2.47it/s, loss=7.12, v_num=8]
# Epoch 97:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.12, v_num=8]
# Epoch 98:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.12, v_num=8]
# Epoch 98: 100%|██████████| 3/3 [00:01<00:00,  2.28it/s, loss=7.12, v_num=8]
# Epoch 98: 100%|██████████| 3/3 [00:01<00:00,  2.28it/s, loss=7.11, v_num=8]
# Epoch 98:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.11, v_num=8]
# Epoch 99:   0%|          | 0/3 [00:00<?, ?it/s, loss=7.11, v_num=8]
# Epoch 99: 100%|██████████| 3/3 [00:01<00:00,  2.42it/s, loss=7.11, v_num=8]
# Epoch 99: 100%|██████████| 3/3 [00:01<00:00,  2.42it/s, loss=7.07, v_num=8]
# Epoch 99: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s, loss=7.07, v_num=8]
#
# Testing: 0it [00:00, ?it/s]
# Testing:  14%|█▍        | 20/141 [00:06<00:40,  3.00it/s]
# Testing:  28%|██▊       | 40/141 [00:08<00:19,  5.17it/s]
# Testing:  43%|████▎     | 60/141 [00:11<00:13,  6.04it/s]
# Testing:  57%|█████▋    | 80/141 [00:13<00:08,  6.98it/s]
# Testing:  71%|███████   | 100/141 [00:15<00:05,  7.96it/s]
# Testing:  85%|████████▌ | 120/141 [00:17<00:02,  8.70it/s]
# Testing:  99%|█████████▉| 140/141 [00:19<00:00,  9.18it/s]Total pixel-level auc-roc score :
# 0.940089471455427
# Total image-level auc-roc score :
# 0.8756539235412475
# test_epoch_end
#
# Testing: 100%|██████████| 141/141 [00:27<00:00,  5.17it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'img_auc': 0.8756539235412475, 'pixel_auc': 0.940089471455427}
# --------------------------------------------------------------------------------
#
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# /usr/local/envs/myenv/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/envs/myenv/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /usr/local/envs/myenv/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name          | Type      | Params
# --------------------------------------------
# 0 | model_t       | ResNet    | 11.7 M
# 1 | model_s       | ResNet    | 11.7 M
# 2 | criterion     | MSELoss   | 0
# 3 | inv_normalize | Normalize | 0
# --------------------------------------------
# 11.7 M    Trainable params
# 11.7 M    Non-trainable params
# 23.4 M    Total params
# 93.516    Total estimated model params size (MB)
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]

# %%
# %load train.py
# %%writefile train.py

import argparse
import torch
from torch.nn import functional as F
from torch import nn
from torchvision import transforms, datasets
from torch.utils.data import Dataset, DataLoader
import cv2
import numpy as np
import os
import glob
import shutil
import time
from torchvision.models import resnet18
from PIL import Image
from sklearn.metrics import roc_auc_score
from torch import nn
import pytorch_lightning as pl
import string
import random
from sklearn.metrics import confusion_matrix

def copy_files(src, dst, ignores=[]):
    src_files = os.listdir(src)
    for file_name in src_files:
        ignore_check = [True for i in ignores if i in file_name]
        if ignore_check:
            continue
        full_file_name = os.path.join(src, file_name)
        if os.path.isfile(full_file_name):
            shutil.copy(full_file_name, os.path.join(dst,file_name))
        if os.path.isdir(full_file_name):
            os.makedirs(os.path.join(dst, file_name), exist_ok=True)
            copy_files(full_file_name, os.path.join(dst, file_name), ignores)

def prep_dirs(root):
    # make sample dir
    sample_path = os.path.join(root, 'sample')
    os.makedirs(sample_path, exist_ok=True)
    # make source code record dir & copy
    source_code_save_path = os.path.join(root, 'src')
    os.makedirs(source_code_save_path, exist_ok=True)
    copy_files('./', source_code_save_path, ['.git','.vscode','__pycache__','logs','README','samples','LICENSE']) # copy source code
    return sample_path, source_code_save_path

def id_generator(size=6, chars=string.ascii_uppercase + string.digits):
    return ''.join(random.choice(chars) for _ in range(size))

def auto_select_weights_file(weights_file_version):
    print()
    version_list = glob.glob(os.path.join(args.project_path, args.category) + '/lightning_logs/version_*')
    version_list.sort(reverse=True, key=lambda x: os.path.getmtime(x))
    if weights_file_version != None:
        version_list = [os.path.join(args.project_path, args.category) + '/lightning_logs/' + weights_file_version] + version_list
    for i in range(len(version_list)):
        # if os.path.exists(os.path.join(version_list[i],'checkpoints')):
        weights_file_path = glob.glob(os.path.join(version_list[i],'checkpoints')+'/*')
        if len(weights_file_path) == 0:
            if weights_file_version != None and i == 0:
                print(f'Checkpoint of {weights_file_version} not found')
            continue
        else:
            weights_file_path = weights_file_path[0]
            if weights_file_path.split('.')[-1] != 'ckpt':
                continue
        print('Checkpoint found : ', weights_file_path)
        print()
        return weights_file_path
    print('Checkpoint not found')
    print()
    return None

#imagenet
mean_train = [0.485, 0.456, 0.406]
std_train = [0.229, 0.224, 0.225]

class MVTecDataset(Dataset):
    def __init__(self, root, transform, gt_transform, phase):
        if phase=='train':
            self.img_path = os.path.join(root, 'train')
        else:
            self.img_path = os.path.join(root, 'test')
            self.gt_path = os.path.join(root, 'ground_truth')
        self.transform = transform
        self.gt_transform = gt_transform
        # load dataset
        self.img_paths, self.gt_paths, self.labels, self.types = self.load_dataset() # self.labels => good : 0, anomaly : 1

    def load_dataset(self):

        img_tot_paths = []
        gt_tot_paths = []
        tot_labels = []
        tot_types = []

        defect_types = os.listdir(self.img_path)

        for defect_type in defect_types:
            if defect_type == 'good':
                img_paths = glob.glob(os.path.join(self.img_path, defect_type) + "/*.png")
                img_tot_paths.extend(img_paths)
                gt_tot_paths.extend([0]*len(img_paths))
                tot_labels.extend([0]*len(img_paths))
                tot_types.extend(['good']*len(img_paths))
            else:
                img_paths = glob.glob(os.path.join(self.img_path, defect_type) + "/*.png")
                gt_paths = glob.glob(os.path.join(self.gt_path, defect_type) + "/*.png")
                img_paths.sort()
                gt_paths.sort()
                img_tot_paths.extend(img_paths)
                gt_tot_paths.extend(gt_paths)
                tot_labels.extend([1]*len(img_paths))
                tot_types.extend([defect_type]*len(img_paths))

        assert len(img_tot_paths) == len(gt_tot_paths), "Something wrong with test and ground truth pair!"

        return img_tot_paths, gt_tot_paths, tot_labels, tot_types

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):
        img_path, gt, label, img_type = self.img_paths[idx], self.gt_paths[idx], self.labels[idx], self.types[idx]
        img = Image.open(img_path).convert('RGB')
        img = self.transform(img)
        if gt == 0:
            gt = torch.zeros([1, img.size()[-2], img.size()[-2]])
        else:
            gt = Image.open(gt)
            gt = self.gt_transform(gt)

        assert img.size()[1:] == gt.size()[1:], "image.size != gt.size !!!"

        return img, gt, label, os.path.basename(img_path[:-4]), img_type

def show_cam_on_image(img, anomaly_map):
    heatmap = cv2.applyColorMap(np.uint8(anomaly_map), cv2.COLORMAP_JET)
    cam = np.float32(heatmap) + np.float32(img)
    cam = cam / np.max(cam)
    return np.uint8(255 * cam)

def cvt2heatmap(gray):
    heatmap = cv2.applyColorMap(np.uint8(gray), cv2.COLORMAP_JET)
    return heatmap

def heatmap_on_image(heatmap, image):
    """
    heatmap: 2D numpy array (H, W) or 3D (H, W, 1)
    image: 3D numpy array (H, W, 3)
    """
    # Eğer heatmap'in boyutu image ile uyuşmuyorsa yeniden boyutlandır
    if heatmap.shape != image.shape[:2]:
        heatmap = cv2.resize(heatmap, (image.shape[1], image.shape[0]))

    # Normalize ve RGB'ye çevir
    heatmap = np.uint8(255 * heatmap) if heatmap.max() <= 1 else np.uint8(heatmap)
    heatmap_color = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    heatmap_color = cv2.cvtColor(heatmap_color, cv2.COLOR_BGR2RGB)

    # Görselle bindir
    out = np.float32(heatmap_color) / 255 + np.float32(image) / 255
    out = out / np.max(out)
    out = np.uint8(255 * out)

    return out

def min_max_norm(image):
    a_min, a_max = image.min(), image.max()
    return (image-a_min)/(a_max - a_min)

def init_weights(m):
    if type(m) == nn.Conv2d:
        torch.nn.init.xavier_uniform(m.weight)

def cal_confusion_matrix(y_true, y_pred_no_thresh, thresh, img_path_list):
    pred_thresh = []
    false_n = []
    false_p = []
    for i in range(len(y_pred_no_thresh)):
        if y_pred_no_thresh[i] > thresh:
            pred_thresh.append(1)
            if y_true[i] == 0:
                false_p.append(img_path_list[i])
        else:
            pred_thresh.append(0)
            if y_true[i] == 1:
                false_n.append(img_path_list[i])

    cm = confusion_matrix(y_true, pred_thresh)
    print(cm)
    print('false positive')
    print(false_p)
    print('false negative')
    print(false_n)


class STPM(pl.LightningModule):
    def __init__(self, hparams):
        super(STPM, self).__init__()

        self.save_hyperparameters(hparams)

        self.init_features()
        def hook_t(module, input, output):
            self.features_t.append(output)
        def hook_s(module, input, output):
            self.features_s.append(output)

        self.model_t = resnet18(pretrained=True).eval()
        for param in self.model_t.parameters():
            param.requires_grad = False

        self.model_t.layer1[-1].register_forward_hook(hook_t)
        self.model_t.layer2[-1].register_forward_hook(hook_t)
        self.model_t.layer3[-1].register_forward_hook(hook_t)

        self.model_s = resnet18(pretrained=False) # default: False
        # self.model_s.apply(init_weights)
        self.model_s.layer1[-1].register_forward_hook(hook_s)
        self.model_s.layer2[-1].register_forward_hook(hook_s)
        self.model_s.layer3[-1].register_forward_hook(hook_s)

        self.criterion = torch.nn.MSELoss(reduction='sum')

        self.gt_list_px_lvl = []
        self.pred_list_px_lvl = []
        self.gt_list_img_lvl = []
        self.pred_list_img_lvl = []
        self.img_path_list = []

        self.data_transforms = transforms.Compose([
                        transforms.Resize((args.load_size, args.load_size), Image.ANTIALIAS),
                        transforms.ToTensor(),
                        transforms.CenterCrop(args.input_size),
                        transforms.Normalize(mean=mean_train,
                                            std=std_train)])
        self.gt_transforms = transforms.Compose([
                        transforms.Resize((args.load_size, args.load_size)),
                        transforms.ToTensor(),
                        transforms.CenterCrop(args.input_size)])
        self.inv_normalize = transforms.Normalize(mean=[-0.485/0.229, -0.456/0.224, -0.406/0.255], std=[1/0.229, 1/0.224, 1/0.255])

    def init_results_list(self):
        self.gt_list_px_lvl = []
        self.pred_list_px_lvl = []
        self.gt_list_img_lvl = []
        self.pred_list_img_lvl = []
        self.img_path_list = []

    def init_features(self):
        self.features_t = []
        self.features_s = []

    def forward(self, x):
        self.init_features()
        x_t = self.model_t(x)
        x_s = self.model_s(x)
        return self.features_t, self.features_s

    def cal_loss(self, fs_list, ft_list):
        tot_loss = 0
        for i in range(len(ft_list)):
            fs = fs_list[i]
            ft = ft_list[i]
            _, _, h, w = fs.shape
            fs_norm = F.normalize(fs, p=2)
            ft_norm = F.normalize(ft, p=2)
            f_loss = (0.5/(w*h))*self.criterion(fs_norm, ft_norm)
            tot_loss += f_loss

        return tot_loss

    def cal_anomaly_map(self, fs_list, ft_list, out_size=224):
        if args.amap_mode == 'mul':
            anomaly_map = np.ones([out_size, out_size])
        else:
            anomaly_map = np.zeros([out_size, out_size])
        a_map_list = []
        for i in range(len(ft_list)):
            fs = fs_list[i]
            ft = ft_list[i]
            fs_norm = F.normalize(fs, p=2)
            ft_norm = F.normalize(ft, p=2)
            a_map = 1 - F.cosine_similarity(fs_norm, ft_norm)
            a_map = torch.unsqueeze(a_map, dim=1)
            a_map = F.interpolate(a_map, size=out_size, mode='bilinear')
            a_map = a_map[0,0,:,:].to('cpu').detach().numpy()
            a_map_list.append(a_map)
            if args.amap_mode == 'mul':
                anomaly_map *= a_map
            else:
                anomaly_map += a_map
        return anomaly_map, a_map_list

    def save_anomaly_map(self, anomaly_map, a_maps, input_img, gt_img, file_name, x_type):
        anomaly_map_norm = min_max_norm(anomaly_map)
        anomaly_map_norm_hm = cvt2heatmap(anomaly_map_norm*255)
        # 64x64 map
        am64 = min_max_norm(a_maps[0])
        am64 = cvt2heatmap(am64*255)
        # 32x32 map
        am32 = min_max_norm(a_maps[1])
        am32 = cvt2heatmap(am32*255)
        # 16x16 map
        am16 = min_max_norm(a_maps[2])
        am16 = cvt2heatmap(am16*255)
        # anomaly map on image
        heatmap = cvt2heatmap(anomaly_map_norm*255)
        hm_on_img = heatmap_on_image(heatmap, input_img)

        # save images
        # file_name = id_generator() # random id
        cv2.imwrite(os.path.join(self.sample_path, f'{x_type}_{file_name}.jpg'), input_img)
        cv2.imwrite(os.path.join(self.sample_path, f'{x_type}_{file_name}_am64.jpg'), am64)
        cv2.imwrite(os.path.join(self.sample_path, f'{x_type}_{file_name}_am32.jpg'), am32)
        cv2.imwrite(os.path.join(self.sample_path, f'{x_type}_{file_name}_am16.jpg'), am16)
        cv2.imwrite(os.path.join(self.sample_path, f'{x_type}_{file_name}_amap.jpg'), anomaly_map_norm_hm)
        cv2.imwrite(os.path.join(self.sample_path, f'{x_type}_{file_name}_amap_on_img.jpg'), hm_on_img)
        cv2.imwrite(os.path.join(self.sample_path, f'{x_type}_{file_name}_gt.jpg'), gt_img)

    def configure_optimizers(self):
        return torch.optim.SGD(self.model_s.parameters(), lr=args.lr, momentum=args.momentum, weight_decay=args.weight_decay)

    def train_dataloader(self):
        image_datasets = MVTecDataset(root=os.path.join(args.dataset_path,args.category), transform=self.data_transforms, gt_transform=self.gt_transforms, phase='train')
        train_loader = DataLoader(image_datasets, batch_size=args.batch_size, shuffle=True, num_workers=0) #, pin_memory=True)
        return train_loader

#     def val_dataloader(self):
#         val_datasets = MVTecDataset(root=os.path.join(args.dataset_path,args.category), transform=self.data_transforms, gt_transform=self.gt_transforms, phase='test')
#         val_loader = DataLoader(val_datasets, batch_size=1, shuffle=False, num_workers=0) #, pin_memory=True) # only work on batch_size=1, now.
#         return val_loader

    def test_dataloader(self):
        test_datasets = MVTecDataset(root=os.path.join(args.dataset_path,args.category), transform=self.data_transforms, gt_transform=self.gt_transforms, phase='test')
        test_loader = DataLoader(test_datasets, batch_size=1, shuffle=False, num_workers=0) #, pin_memory=True) # only work on batch_size=1, now.
        return test_loader

    def on_train_start(self):
        self.model_t.eval() # to stop running_var move (maybe not critical)
        self.sample_path, self.source_code_save_path = prep_dirs(self.logger.log_dir)

#     def on_validation_start(self):
#         self.init_results_list()

    def on_test_start(self):
        self.init_results_list()
        self.sample_path, self.source_code_save_path = prep_dirs(self.logger.log_dir)

    def training_step(self, batch, batch_idx):
        x, _, _, file_name, _ = batch
        features_t, features_s = self(x)
        loss = self.cal_loss(features_s, features_t)
        self.log('train_loss', loss, on_epoch=True)
        return loss

#     def validation_step(self, batch, batch_idx):
#         x, gt, label, file_name, x_type = batch
#         features_t, features_s = self(x)
#         # Get anomaly map
#         anomaly_map, _ = self.cal_anomaly_map(features_s, features_t, out_size=args.input_size)

#         gt_np = gt.cpu().numpy().astype(int)
#         self.gt_list_px_lvl.extend(gt_np.ravel())
#         self.pred_list_px_lvl.extend(anomaly_map.ravel())
#         self.gt_list_img_lvl.append(label.cpu().numpy()[0])
#         self.pred_list_img_lvl.append(anomaly_map.max())
#         self.img_path_list.extend(file_name)

    def test_step(self, batch, batch_idx):
        x, gt, label, file_name, x_type = batch

        # Öğrenci ve öğretmen model çıktıları
        features_t, features_s = self(x)

        # Anomali haritası ve detaylı katman çıktı haritaları
        anomaly_map, a_map_list = self.cal_anomaly_map(features_s, features_t, out_size=args.input_size)

        # Ground truth mask (örneğin 1x1x256x256)
        gt_np = gt.cpu().numpy().astype(np.uint8)

        # ✅ boyut kontrolü: anomaly_map boyutu ile GT aynı mı?
        if anomaly_map.shape != gt_np[0][0].shape:
          anomaly_map = cv2.resize(anomaly_map, (gt_np.shape[2], gt_np.shape[1]))

        # ✅ Flatten edip listeye ekle
        self.gt_list_px_lvl.extend(gt_np[0][0].flatten())
        self.pred_list_px_lvl.extend(anomaly_map.flatten())

        # Image-level listeler
        self.gt_list_img_lvl.append(label.cpu().numpy()[0])
        self.pred_list_img_lvl.append(anomaly_map.max())
        self.img_path_list.extend(file_name)

        # ✅ Görseli normalize et ve uint8'e çevir
        x = self.inv_normalize(x)
        input_x = x[0].permute(1, 2, 0).cpu().numpy() * 255
        input_x = np.clip(input_x, 0, 255).astype(np.uint8)
        input_x = cv2.cvtColor(input_x, cv2.COLOR_RGB2BGR)

        # ✅ GT mask görseli [0,255] skalasında
        gt_vis = gt_np[0][0] * 255

        # ✅ Kaydet
        self.save_anomaly_map(anomaly_map, a_map_list, input_x, gt_vis, file_name[0], x_type[0])


#     def validation_epoch_end(self, outputs):
#         pixel_auc = roc_auc_score(self.gt_list_px_lvl, self.pred_list_px_lvl)
#         img_auc = roc_auc_score(self.gt_list_img_lvl, self.pred_list_img_lvl)
#         values = {'pixel_auc': pixel_auc, 'img_auc': img_auc}
#         self.log_dict(values)

    def test_epoch_end(self, outputs):
        print("Total pixel-level auc-roc score :")
        pixel_auc = roc_auc_score(self.gt_list_px_lvl, self.pred_list_px_lvl)
        print(pixel_auc)
        print("Total image-level auc-roc score :")
        img_auc = roc_auc_score(self.gt_list_img_lvl, self.pred_list_img_lvl)
        print(img_auc)
        print('test_epoch_end')
        values = {'pixel_auc': pixel_auc, 'img_auc': img_auc}
        self.log_dict(values)
        # # 값 분리
        # anomaly_list = []
        # normal_list = []
        # for i in range(len(self.gt_list_img_lvl)):
        #     if self.gt_list_img_lvl[i] == 1:
        #         anomaly_list.append(self.pred_list_img_lvl[i])
        #     else:
        #         normal_list.append(self.pred_list_img_lvl[i])

        # # thresholding
        # cal_confusion_matrix(self.gt_list_img_lvl, self.pred_list_img_lvl, img_path_list = self.img_path_list, thresh = 0.00097)
        # print()
        # with open(args.project_path + r'/results.txt', 'a') as f:
        #     f.write(self.logger.log_dir + '\n')
        #     f.write(args.category + ' : ' + str(values) + '\n')


def get_args():
    parser = argparse.ArgumentParser(description='ANOMALYDETECTION')
    parser.add_argument('--phase', choices=['train','test'], default='train')
    parser.add_argument('--dataset_path', default=r'D:\Dataset\mvtec_anomaly_detection') #/tile') #'/home/changwoo/hdd/datasets/mvtec_anomaly_detection'
    parser.add_argument('--category', default='grid')
    parser.add_argument('--num_epochs', default=100)
    parser.add_argument('--lr', default=0.4)
    parser.add_argument('--momentum', default=0.9)
    parser.add_argument('--weight_decay', default=0.0001)
    parser.add_argument('--batch_size', default=32)
    parser.add_argument('--load_size', default=256) # 256
    parser.add_argument('--input_size', default=256)
    parser.add_argument('--project_path', default=r'D:\Project_Train_Results\mvtec_anomaly_detection\210624\test') #'/home/changwoo/hdd/project_results/STPM_lightning/210621') #210605') #
    parser.add_argument('--save_src_code', default=True)
    parser.add_argument('--save_anomaly_map', default=True)
    parser.add_argument('--amap_mode', choices=['mul','sum'], default='mul')
    parser.add_argument('--val_freq', default=5)
    parser.add_argument('--weights_file_version', type=str, default=None)
    # parser.add_argument('--weights_file_version', type=str, default='version_1')
    args = parser.parse_args()
    return args

if __name__ == '__main__':

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    args = get_args()

    trainer = pl.Trainer.from_argparse_args(args, default_root_dir=os.path.join(args.project_path, args.category), max_epochs=args.num_epochs, gpus=[0]) #, check_val_every_n_epoch=args.val_freq,  num_sanity_val_steps=0) # ,fast_dev_run=True)

    if args.phase == 'train':
        model = STPM(hparams=args)
        trainer.fit(model)
        trainer.test(model)
    elif args.phase == 'test':
        # select weight file.
        weights_file_path = auto_select_weights_file(args.weights_file_version) # select latest weight if args.weights_file_version == None

        if weights_file_path != None:
            model = STPM(hparams=args).load_from_checkpoint(weights_file_path)
            trainer.test(model)
        else:
            print('Weights file is not found!')
# Out:
# Overwriting train.py

# %%
# !conda run -n myenv python /content/drive/MyDrive/STPM_12_04_2024/STPM_anomaly_detection/train.py \
--phase test \
--dataset_path /content/drive/MyDrive/STPM_12_04_2024/STPM_anomaly_detection/mvtec_anomaly_detection \
--category wood \
--project_path /content/drive/MyDrive/STPM_12_04_2024/STPM_anomaly_detection
# Out:
# Checkpoint found :  /content/drive/MyDrive/STPM_12_04_2024/STPM_anomaly_detection/wood/lightning_logs/version_8/checkpoints/epoch=99-step=299.ckpt
#
#
# Testing: 0it [00:00, ?it/s]
# Testing:  14%|█▍        | 20/141 [00:05<00:35,  3.40it/s]
# Testing:  28%|██▊       | 40/141 [00:07<00:17,  5.83it/s]
# Testing:  43%|████▎     | 60/141 [00:09<00:10,  7.50it/s]
# Testing:  57%|█████▋    | 80/141 [00:11<00:07,  7.74it/s]
# Testing:  71%|███████   | 100/141 [00:14<00:05,  8.08it/s]
# Testing:  85%|████████▌ | 120/141 [00:15<00:02,  8.83it/s]
# Testing:  99%|█████████▉| 140/141 [00:17<00:00,  9.36it/s]
# Testing: 100%|██████████| 141/141 [00:17<00:00,  9.35it/s]Total pixel-level auc-roc score :
# 0.940089471455427
# Total image-level auc-roc score :
# 0.8756539235412475
# test_epoch_end
#
# Testing: 100%|██████████| 141/141 [00:24<00:00,  5.85it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'img_auc': 0.8756539235412475, 'pixel_auc': 0.940089471455427}
# --------------------------------------------------------------------------------
#
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# /usr/local/envs/myenv/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/envs/myenv/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /usr/local/envs/myenv/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /usr/local/envs/myenv/lib/python3.8/site-packages/pytorch_lightning/utilities/cloud_io.py:33: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=map_location)
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]

# %%
import matplotlib.pyplot as plt
from PIL import Image

# Resim dosya yolları
img_paths = [
    "/content/drive/MyDrive/STPM_12_04_2024/STPM_anomaly_detection/wood/lightning_logs/version_8/sample/defect_100000003.jpg",
    "/content/drive/MyDrive/STPM_12_04_2024/STPM_anomaly_detection/wood/lightning_logs/version_8/sample/defect_100000003_amap.jpg",
    "/content/drive/MyDrive/STPM_12_04_2024/STPM_anomaly_detection/wood/lightning_logs/version_8/sample/defect_100000003_amap_on_img.jpg",
    "/content/drive/MyDrive/STPM_12_04_2024/STPM_anomaly_detection/wood/lightning_logs/version_8/sample/defect_100000003_gt.jpg",
]

# Başlıklar
titles = ["Original", "Anomaly Map", "Overlay on Image", "Ground Truth"]

# Görselleri yükle
images = [Image.open(path) for path in img_paths]

# Yan yana göster
plt.figure(figsize=(20, 5))
for i, (img, title) in enumerate(zip(images, titles)):
    plt.subplot(1, 4, i + 1)
    plt.imshow(img)
    plt.title(title)
    plt.axis('off')
plt.tight_layout()
plt.show()
